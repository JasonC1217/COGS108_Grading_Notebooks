# %% [markdown]
# # Group Progress Survey Extra Credit Grading
#
# Author: Jason Chen
#
# 12/17/2023

# %% [markdown]
# ## How to use this script:
#
# 1. Go to Canvas, and generate the personal token, paste in the cell below.
#     - To do so, go to canvas.ucsd.edu, Account -> Settings -> Approved Integrations -> + New Access Token. Generate the access token, set the purpose and the expiration date, copy it.
# 2. Get the course id and assignment id, paste in the cell below.
# 3. Download the responses for Group Progress Survey as a csv file, upload it under the same directory as this script.
# 4. Paste the file path and the column name containing the group numbers in the cell below.
# 5. Run all the cells to publish score.

# %%
# Import packages needed:

import pandas as pd
import re
import requests
import csv
# Out:
# /home/grader-cogs108-02/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/grader-cogs108-02/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Initialize the variables:

# The URL of Canvas api, no need to change.
API_URL = "https://canvas.ucsd.edu"

# The access token for Canvas, need to generate on Canvas website and paste here.
API_KEY = "13171~m5qrWdND5GevNLg9WfeHzoY8pghyfZQWUT7mDo5G4npFEXvLucRuNChhzZ9HKxIG"

# The course id, can be found on Canvas.
COURSE_ID = "48733"

# The assignment id, can be found on Canvas.
ASSIGNMENT_ID = "693709"

# The score for the assignmnet Group Progress Survey, can be changed accordingly.
SCORE = 0.5

# The path of csv file contains responses for Group Progress Survey.
file_path = "COGS 108 FA23 - Group Project Progress - Weekly Form (Responses) - Form Responses 1.csv"

# The column name that contains the emails.
emails = "Email Address"

# The column name that comtains weeks they completed the survey.
weeks = "For which week are you completing this form?"

# %%
# Check for unique submission ids:
df = pd.read_csv(file_path)
len(df["Email Address"].unique())
# Out:
# 632

# %%
def get_student_ids(course_id, api_url, api_key):
    endpoint = f"{api_url}/api/v1/courses/{course_id}/users"
    headers = {"Authorization": f"Bearer {api_key}"}
    student_ids = {}

    while endpoint:
        response = requests.get(endpoint, headers=headers)
        if response.status_code == 200:
            users = response.json()
            for user in users:
                login_id = user.get('login_id')
                student_id = user.get('id')
                if login_id and student_id:
                    student_ids[login_id] = student_id

            links = response.links
            endpoint = links['next']['url'] if 'next' in links else None
        else:
            print("Failed to retrieve users: ", response.text)
            break

    return student_ids

# Usage

student_ids = get_student_ids(COURSE_ID, API_URL, API_KEY)

# %%
student_ids
# Out:
# {'jabondano': 170728,
#  'aaboushaaban': 167080,
#  'madebiyi': 169141,
#  'sragarwa': 95700,
#  'a6aggarw': 103380,
#  'adagrawal': 137772,
#  'a1agrawal': 133353,
#  'a2akbari': 132045,
#  'naalami': 9382,
#  'aalghazouli': 172661,
#  'rmali': 101023,
#  'jalinas': 167717,
#  'janayagarcia': 127201,
#  'aapiado': 108717,
#  'karcos': 130147,
#  'jariss': 168166,
#  'jrarreguin': 135193,
#  'jartley': 170159,
#  'narumugam': 128169,
#  'adarun': 132164,
#  'basami': 171360,
#  'hashcroft': 139799,
#  'aaverbuj': 167025,
#  'suaye': 170628,
#  'ababoescu': 170353,
#  'mbach': 136327,
#  'nbajaj': 100406,
#  'rbaldoz': 131582,
#  'lballest': 96800,
#  'jbanawa': 81727,
#  'dbansal': 159651,
#  'abanwait': 104930,
#  'tibao': 126284,
#  'gbarrosk': 97951,
#  'bbeeson': 108019,
#  'sboddy': 138313,
#  'nboloori': 95060,
#  'aborjasquintanilla': 107686,
#  'hbrownell': 107869,
#  'y2bu': 133383,
#  'mbuan': 100907,
#  'bbuckhan': 103343,
#  'bbudiputra': 139975,
#  'bjburke': 170924,
#  'meburrows': 124994,
#  'gbutters': 135159,
#  'obychenkov': 164044,
#  'h3cai': 131086,
#  'lecai': 97237,
#  'yic075': 136562,
#  'z4cai': 168309,
#  'accalibuso': 129102,
#  'acalza': 131533,
#  'aacameron': 134170,
#  'j8cao': 133538,
#  'licarrillo': 167122,
#  'dcarrion': 108027,
#  'jtcastillo': 132711,
#  'iachai': 107324,
#  'bschan': 103400,
#  'evchan': 133822,
#  'kec021': 133401,
#  'swchan': 130947,
#  'w9chan': 169677,
#  'k1chang': 99725,
#  'hic001': 162694,
#  'a3chao': 170488,
#  'achavarria': 132115,
#  'stchavez': 97137,
#  'mic035': 170684,
#  'azc001': 140274,
#  'q8chen': 98371,
#  'bhc001': 107245,
#  'mec005': 95952,
#  'gjchen': 101556,
#  'jac018': 130313,
#  'xic007': 54217,
#  'jpc005': 134294,
#  'jcc002': 133569,
#  'mec009': 168449,
#  'sjc003': 134113,
#  'yic079': 140376,
#  'yic057': 103045,
#  'sic018': 132427,
#  'chc057': 132491,
#  'h9cheng': 137113,
#  'i1cheng': 163522,
#  'nchepuri': 129432,
#  'p1chiang': 167935,
#  'enchin': 130151,
#  'kwchin': 107369,
#  'ehcho': 132330,
#  'h2choi': 15469,
#  'yechoi': 102793,
#  'kjchou': 134440,
#  'shchow': 94992,
#  'schowbey': 136274,
#  'achowdhry': 133494,
#  'brchu': 133630,
#  'ntchung': 134501,
#  'jmcole': 138819,
#  'tmcooper': 136945,
#  'acrawley': 141212,
#  'ncrawley': 141509,
#  'nccronin': 107444,
#  'j5dai': 136033,
#  'ldai': 95488,
#  'jedang': 133457,
#  'mmdavid': 134808,
#  'mdayanan': 92379,
#  'jdegraaf': 141132,
#  'hdehaini': 167691,
#  'eldelrosario': 135792,
#  'ezdeng': 169672,
#  'cdermanuelian': 107634,
#  'adevineni': 136736,
#  'fdiamond': 164723,
#  'mndiaz': 108721,
#  'gdietz': 105246,
#  'mdimitropoulouka': 106164,
#  'vdinesh': 107900,
#  'yid016': 128164,
#  'bdioneda': 168989,
#  'chd004': 170575,
#  'k4do': 105241,
#  'wdoan': 91600,
#  'fdong': 129696,
#  'j3dong': 98294,
#  'ddonskoy': 135973,
#  'ddoppala': 104477,
#  'andsouza': 142480,
#  'zedu': 97103,
#  'bdubois': 166952,
#  'mdulansk': 98313,
#  'hduong': 100344,
#  'ldwight': 107541,
#  'jweconomy': 137367,
#  'kekhlassi': 171654,
#  'senkhjargal': 168007,
#  'fenriquez': 166981,
#  'cerpeldi': 66006,
#  'jevalle': 99726,
#  'ctevans': 128331,
#  'sevtimova': 134831,
#  'lfasting': 170686,
#  'gfeghali': 168613,
#  'dfeliton': 129335,
#  'bfernandez': 108648,
#  'sfinch': 102927,
#  'lsfleig': 134432,
#  'jfleischer': 11286,
#  'kfleisch': 101491,
#  'hsflores': 130921,
#  'kefong': 99005,
#  'tfoster': 80996,
#  'sfrianeza': 170014,
#  'h6fu': 103949,
#  'xif001': 131623,
#  'bfune': 128425,
#  'jefung': 136551,
#  'pgaikwad': 135771,
#  'jgamm': 136823,
#  'lgan': 135320,
#  'a1ganesa': 94971,
#  'bigao': 131549,
#  'kdgao': 34976,
#  'e8garcia': 15279,
#  'kggarcia': 129735,
#  'mag026': 96896,
#  'sgaribayzaguilan': 107716,
#  'lgasser': 108020,
#  'pgaudet': 169328,
#  'aghai': 100638,
#  'nghosh': 129783,
#  'tgibbs': 17362,
#  'dgines': 136579,
#  'sgoh': 100151,
#  'sgong': 129503,
#  'v8gonzal': 102641,
#  'eag002': 133648,
#  'efg004': 167197,
#  'akgoswam': 99998,
#  'jgow': 103156,
#  'grader-cogs108-02': 145946,
#  'lgranger': 125371,
#  'jig036': 169969,
#  'kgugnani': 99002,
#  'mgujavarthi': 168304,
#  'jig015': 136257,
#  'xig003': 132230,
#  'xig001': 130702,
#  'yag007': 136633,
#  'hgurusan': 96754,
#  'bbhaber': 100805,
#  'bhacia': 107271,
#  'hhai': 168375,
#  'kham': 133445,
#  'ihamid': 138189,
#  'z4han': 107501,
#  'chao': 132420,
#  'vhasthi': 128912,
#  'jih063': 128344,
#  'xuh011': 130264,
#  'eheffernan': 107713,
#  'nihegde': 96969,
#  'phelcl': 96271,
#  'ahensel': 102216,
#  'arh003': 131336,
#  'ahewig': 141110,
#  'khidayat': 169710,
#  'vhinds': 128882,
#  'shirota': 135005,
#  'khho': 168681,
#  'lmho': 137646,
#  'qnhoang': 103386,
#  'gihoang': 166905,
#  'joh032': 170314,
#  'kkhoang': 108035,
#  'mlholland': 108302,
#  'choman': 130744,
#  'qihou': 102402,
#  'jchowe': 167662,
#  'zhh022': 131129,
#  'hohu': 105349,
#  'jih101': 168099,
#  'q7hu': 134529,
#  'vhu': 139090,
#  'xih035': 132190,
#  'jah003': 100114,
#  'keh004': 132079,
#  'roh002': 130323,
#  'r8huang': 100644,
#  'vihuang': 141729,
#  'yih045': 131674,
#  'pyhui': 100879,
#  'qhui': 95738,
#  'tchui': 95493,
#  'yuhung': 129391,
#  'diqbal': 110529,
#  'bjackola': 97234,
#  'ejao': 100403,
#  'ajayamohan': 165981,
#  'vjegadhe': 100837,
#  'yuj036': 128109,
#  'bojia': 130053,
#  'hojia': 168159,
#  'ajiang': 100080,
#  'c5jiang': 132637,
#  'dzjiang': 96236,
#  'fjiang': 129312,
#  'rojiang': 138145,
#  'wej002': 169754,
#  'jrjimenez': 136152,
#  'rojin': 169794,
#  'tjoel': 104952,
#  'ajohari': 83646,
#  'ajuljulian': 107548,
#  'aujung': 134700,
#  'ekakarla': 129808,
#  'wkam': 129324,
#  'jkaminsky': 135379,
#  'akamra': 169510,
#  'kekang': 139467,
#  'k9kang': 168471,
#  'rkant': 167849,
#  'amkao': 129728,
#  'jkarim': 171056,
#  'skaroval': 101920,
#  'pkatukojwala': 134395,
#  'ckavanagh': 133985,
#  'mdkawakami': 160810,
#  'tkawser': 139259,
#  'nekeodar': 45393,
#  'nokerendian': 163873,
#  'okhalil': 170460,
#  'dekhan': 96240,
#  'prkhanna': 132061,
#  'zakhater': 170679,
#  'mkhawaja': 171134,
#  'dki': 68706,
#  'dnkim': 68026,
#  'erk004': 131083,
#  'tkk002': 171314,
#  'hwk001': 99704,
#  'eyk005': 133737,
#  'juk019': 137726,
#  'kjk004': 132225,
#  'msk001': 77671,
#  'mik023': 103639,
#  'smkim': 108597,
#  'yek003': 103297,
#  'pking': 129223,
#  'aklinefelter': 127254,
#  'j3ko': 139887,
#  'nako': 170938,
#  'rkohli': 100361,
#  'd3kong': 127389,
#  'arkonnova': 130232,
#  'kku': 134050,
#  's4kumar': 130922,
#  'hykung': 168962,
#  'akunitad': 103910,
#  'jakwak': 16293,
#  'vkwan': 135894,
#  'gkweon': 103375,
#  'kkla': 132533,
#  'mslai': 131512,
#  'y2lai': 84206,
#  'aklam': 131574,
#  'pklam': 101886,
#  'jkl015': 170594,
#  'n2lam': 95531,
#  'ejlau': 107542,
#  'claw': 101841,
#  'jlazcano': 173383,
#  'bnle': 98862,
#  'gile': 132547,
#  'mhle': 133030,
#  'bnl002': 107481,
#  'chl147': 133651,
#  'dhl001': 132117,
#  'yul196': 131330,
#  'jjl027': 104544,
#  'jul050': 106002,
#  'kal030': 139361,
#  'kyl011': 141488,
#  'mml002': 132734,
#  'm5lee': 107151,
#  'nal008': 130704,
#  'nol001': 132979,
#  'tll001': 108708,
#  'mnleong': 129309,
#  'jyli': 94437,
#  'chl125': 128347,
#  'zil089': 170870,
#  'f3li': 100900,
#  'gjl001': 131066,
#  'jal039': 100048,
#  'jil237': 130300,
#  'lil010': 105419,
#  'mil049': 127861,
#  'ouli': 130912,
#  'qil008': 43232,
#  'rhli': 103513,
#  'shl127': 170346,
#  't8li': 95984,
#  'wuli': 104277,
#  'zil090': 170573,
#  'jil249': 136582,
#  'saliang': 131821,
#  's7liang': 127779,
#  'jyl013': 96265,
#  'zlim': 171627,
#  'del021': 157393,
#  'etl003': 134761,
#  'rhlin': 97257,
#  'chl135': 131073,
#  'cll006': 134367,
#  'rul020': 128339,
#  'mgliu': 138671,
#  'sal038': 131644,
#  'rlizaranmolina': 168713,
#  'jlizarra': 93205,
#  'mloeraar': 25140,
#  'vlohia': 95913,
#  'eplong': 130763,
#  'ealopez': 131585,
#  'ccl011': 132220,
#  'dhl003': 137351,
#  'yilou': 131104,
#  'gluengowoods': 168256,
#  'sxluong': 166995,
#  'j2lyu': 95525,
#  'a2ma': 133124,
#  'jum004': 134507,
#  'k6ma': 98047,
#  'lim007': 171286,
#  'zamahmood': 107746,
#  'smai': 97892,
#  'tbmai': 101569,
#  's2malik': 134312,
#  'samann': 168979,
#  'nmarthen': 136716,
#  'dam001': 96131,
#  'amasek': 129287,
#  'amathi': 99618,
#  'yamazaheri': 167191,
#  'mmckenziegarand': 168298,
#  'smejia': 107367,
#  'mmelkony': 102965,
#  'swmenon': 99379,
#  'rmeserve': 107002,
#  'anmiao': 105019,
#  's4min': 136797,
#  'emiranda': 99596,
#  'a1mishra': 107645,
#  'pmondrag': 102711,
#  'mamontano': 133108,
#  'gmoreau': 92397,
#  'mamorera': 133409,
#  'amorris': 103212,
#  'nmummala': 94372,
#  'mmuruganandam': 134467,
#  'shmusini': 131434,
#  'anag': 96039,
#  'unaik': 128282,
#  'p1nair': 137768,
#  'anarasimhan': 168611,
#  'sanarayanan': 131668,
#  'knelakon': 52040,
#  'akn022': 4273,
#  'ctn005': 98982,
#  'dkn003': 135702,
#  'emn005': 133112,
#  'kan005': 128163,
#  'kan024': 170853,
#  'ktn013': 95337,
#  'khn009': 104765,
#  'khn034': 54366,
#  'ltn011': 135736,
#  'nhn007': 109883,
#  'rmn001': 135690,
#  'rin002': 167989,
#  'tkn003': 133366,
#  'tan003': 103163,
#  'tin003': 126389,
#  'ton002': 128855,
#  'wvnguyen': 78811,
#  'snguyenphuoc': 106259,
#  'c5ni': 47697,
#  'jnishi': 104244,
#  'sbnorthrop': 124614,
#  'molmedo': 100730,
#  'klomar': 44931,
#  'j1ouyang': 129207,
#  'iozekici': 173393,
#  'tpagela': 106148,
#  'spamudji': 104871,
#  'kpansuri': 96332,
#  'npantfoerder': 140407,
#  'rpaquia': 107039,
#  'npareddy': 95061,
#  'anp072': 68746,
#  'bop002': 172884,
#  'jup006': 58473,
#  'khpark': 107315,
#  'saparvathaneni': 129333,
#  'v7patel': 133677,
#  'rpenchala': 131495,
#  'ipendlet': 99674,
#  'fepeng': 130719,
#  'fpeng': 108261,
#  'rpeng': 24678,
#  'z7peng': 99613,
#  'tpeterso': 104848,
#  'qphamnguyen': 136685,
#  'ttp007': 168241,
#  'baphan': 133705,
#  'c8phan': 124815,
#  'hvphan': 129850,
#  'htphan': 133727,
#  'apimple': 129125,
#  'spital': 127729,
#  'jpon': 100011,
#  'kponce': 132502,
#  'gpong': 166554,
#  'gprabhak': 93612,
#  'pprabhu': 135203,
#  'v1prado': 167018,
#  'anprasad': 98083,
#  'apremkumar': 135797,
#  'zpun': 169317,
#  'spuri': 107429,
#  'apurohit': 131018,
#  'pputtapa': 96312,
#  'k6qin': 63257,
#  'y7qin': 95289,
#  'ziqiu': 134557,
#  'kqu': 96744,
#  'grquach': 133551,
#  't1quach': 128375,
#  'niquach': 128522,
#  'bquijada': 127412,
#  's1rai': 97451,
#  'asraj': 132839,
#  'karaj': 168441,
#  'arraja': 156355,
#  'arajiv': 99424,
#  'arakha': 169157,
#  'sbramire': 102671,
#  'xjramirez': 134153,
#  'j8ramos': 167673,
#  'n1rashid': 127796,
#  'arasin': 94470,
#  'aravishankar': 132074,
#  'kkray': 137403,
#  'prebala': 133337,
#  'nregli': 66260,
#  'mrenteri': 99879,
#  'nrepetti': 96941,
#  'rriosram': 16685,
#  'crishi': 99612,
#  'groberg': 131608,
#  'arobertson': 129316,
#  'e7rodrig': 92025,
#  'hrodriguezterry': 128524,
#  'iroque': 102672,
#  'srote': 166914,
#  'drovira': 107161,
#  'trucker': 104423,
#  'awrussell': 134387,
#  'jasabio': 173277,
#  'asagundo': 26607,
#  'ssahar': 169974,
#  'shsam': 138732,
#  'mas026': 169558,
#  'pssanchez': 135971,
#  'r6sanche': 105081,
#  'gsandhu': 135425,
#  'ssankavaram': 108289,
#  'ssantacruzibarra': 158886,
#  'mesantos': 99397,
#  'vsastry': 101352,
#  'bsathappan': 133359,
#  'arsaxena': 127001,
#  'sschlagheck': 135381,
#  'hlschwartz': 129504,
#  'pseck': 103446,
#  'kseely': 99861,
#  'bsepulve': 103575,
#  'tshaikh': 141011,
#  'hushan': 134401,
#  'tsharifi': 170551,
#  'esharkov': 100640,
#  's5sharma': 135820,
#  'cas007': 129809,
#  'm3shen': 134098,
#  'xushi': 131007,
#  'dshi': 101203,
#  'dshin': 96233,
#  'hhshin': 134352,
#  'tjshin': 136512,
#  'n1shinde': 169380,
#  'c1shu': 133417,
#  'vshu': 103272,
#  'x1shu': 133356,
#  'arshukla': 132235,
#  'jshyu': 136075,
#  'asierra': 105137,
#  'osimonds': 171065,
#  'jsimpauco': 130660,
#  'gus001': 125424,
#  'r1singh': 97105,
#  'ysingh': 104873,
#  'bsison': 169757,
#  'ssitu': 102719,
#  'anslyker': 128257,
#  'asmithwick': 160049,
#  'miso': 168889,
#  'json': 95295,
#  'e7song': 136784,
#  'kjsong': 140061,
#  'asonti': 136616,
#  'kpstern': 104281,
#  'sdsteven': 94407,
#  'estratford': 134302,
#  'jstreett': 134408,
#  'asubbarao': 173394,
#  'tsugita': 107961,
#  'e2sun': 108148,
#  'mis005': 104212,
#  'mis008': 168675,
#  'rzsun': 137866,
#  'rsunku': 133033,
#  'wsupian': 133476,
#  'arsureshkumar': 158104,
#  'ansuresh': 134012,
#  'vswamy': 132071,
#  'mszeto': 133026,
#  'stalanki': 103007,
#  'm1tam': 104875,
#  'cktan': 30341,
#  'jit011': 170322,
#  'mntan': 102013,
#  'cht019': 170169,
#  'mjtang': 136062,
#  'otang': 126395,
#  'fetang': 129664,
#  'y6tang': 97203,
#  'jtanurdjaja': 132129,
#  'rtay': 103234,
#  'sytaylor': 107982,
#  'jtello': 136555,
#  'brobertthaddeus': 136672,
#  'jqthai': 135711,
#  'tithai': 166891,
#  'nthiyagarajan': 135799,
#  'dithomas': 171542,
#  'bthome': 107802,
#  'yut009': 132991,
#  'lto': 108758,
#  'ctomlin': 134875,
#  'htonnu': 135976,
#  'ant034': 171136,
#  'dktran': 108509,
#  'pjtran': 106672,
#  'sat001': 107572,
#  'ntrejo': 101155,
#  'trtruong': 101983,
#  'j1tsai': 97278,
#  'htse': 132773,
#  'antseng': 168053,
#  'jtutak': 129817,
#  'vtyagi': 133665,
#  'suppu': 33060,
#  'rusmanova': 138528,
#  'svaldimarsdottir': 166937,
#  'ajvalencia': 130681,
#  'svallumchetla': 133913,
#  'kvankirk': 106329,
#  'ivarela': 100575,
#  'avasanth': 129241,
#  'a2vazque': 99845,
#  'ivenzon': 170550,
#  'atvilays': 48388,
#  'svirk': 99247,
#  'pviwatkurkul': 132673,
#  'ahvu': 131757,
#  'ervu': 168424,
#  'kmvu': 127733,
#  'kdvu': 133504,
#  'trvu': 126417,
#  'ctwalsh': 136785,
#  'z4wan': 101595,
#  'shw050': 102630,
#  'anw010': 129567,
#  'shw081': 132336,
#  'jhw009': 139261,
#  'haw086': 169638,
#  'kuw010': 129236,
#  'yuw096': 97061,
#  'l3wang': 96202,
#  'piw001': 140172,
#  'ruw008': 98708,
#  'siw031': 133412,
#  'yiw072': 95029,
#  'thw001': 95906,
#  'etwaters': 168429,
#  'z5wei': 129200,
#  'bwelles': 136202,
#  'mwelsome': 95013,
#  'x7wen': 136884,
#  'anwen': 136454,
#  'mwidyadh': 102730,
#  'jaw018': 133607,
#  'juw024': 103541,
#  'khw001': 132525,
#  'kew027': 169598,
#  'rdwong': 129220,
#  'v9wong': 171110,
#  'wcw003': 170760,
#  'kewoo': 136387,
#  'anw002': 108445,
#  'daw010': 136924,
#  'd7wu': 99995,
#  'd5wu': 96248,
#  'haw189': 10097,
#  'jzwu': 95712,
#  'jiw118': 133594,
#  'jjwu': 108008,
#  'juw050': 167667,
#  't8wu': 100057,
#  'yuw135': 129639,
#  'bbxia': 130120,
#  'mxian': 97414,
#  'alxiao': 133096,
#  'r3xiao': 136035,
#  'yaxiao': 103423,
#  'ejxiong': 131814,
#  'max003': 99841,
#  'p3xu': 131732,
#  'yax016': 167961,
#  'zhx003': 100748,
#  'c4yan': 99288,
#  'yyanagawa': 105446,
#  'boyang': 38116,
#  'r6yang': 96899,
#  'hey001': 103623,
#  'huy005': 128795,
#  'jey013': 136073,
#  'yuy004': 69877,
#  'jyangari': 129582,
#  'lyazouri': 108552,
#  'a1ye': 107372,
#  'eyenikomshian': 134241,
#  'z5ying': 8567,
#  'jyyip': 101860,
#  'jyip': 95006,
#  'dyonemura': 106076,
#  'joy005': 106490,
#  'key010': 137002,
#  'key009': 132152,
#  'hsy002': 170865,
#  'tyyu': 97235,
#  'xiy005': 96286,
#  'yay019': 71626,
#  'z2yu': 91636,
#  'z8yuan': 131877,
#  'czakkour': 106880,
#  'boz002': 138620,
#  'yiz029': 95825,
#  'liz035': 137051,
#  'jiz145': 127808,
#  'jiz147': 129253,
#  'k3zhang': 34465,
#  'lez002': 95904,
#  'luz010': 127844,
#  'miz030': 166846,
#  'nwzhang': 132703,
#  'zhz084': 130112,
#  'zhz044': 94249,
#  'ziz057': 134859,
#  'yuz159': 127238,
#  'jazheng': 99571,
#  'shz054': 130720,
#  'ruzhong': 130569,
#  'y4zhong': 98017,
#  'alz007': 165074,
#  'e4zhou': 171822,
#  'k9zhou': 129852,
#  'lazhou': 102380,
#  'liz009': 96199,
#  'shz040': 109592,
#  'azhuchou': 97046,
#  'b2zhu': 129500,
#  'brzhu': 133015,
#  'haz042': 103047,
#  'r2zhu': 126239,
#  'yiz123': 104071,
#  'yiz036': 96826,
#  'l1zhuo': 132227,
#  'bzou': 105565,
#  'hazou': 127805}

# %%
len(student_ids)
# Out:
# 743

# %%
def extract_weeks_completed(file_path, email_column, week_column):
    
    """
    Function to extract the number of weeks each email address (first part before '@') completed the survey.

    Parameters:
    file_path (str): The path to the CSV file.
    email_column (str): The column name in the CSV file that contains the email addresses.
    week_column (str): The column name in the CSV file that contains the week information.

    Returns:
    dict: A dictionary with the login ids as keys and the number of weeks completed as values.
    """
    
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Extract the first part of the email address
    data['login_id'] = data[email_column].apply(lambda x: x.split('@')[0])

    # Group by the first part of the email and count unique weeks
    weeks_per_email = data.groupby('login_id')[week_column].nunique()

    # Convert to dictionary
    weeks_completed_dict = weeks_per_email.to_dict()

    return weeks_completed_dict

# %%
students_with_weeks_completed = extract_weeks_completed(file_path, emails, weeks)

# %%
students_with_weeks_completed
# Out:
# {'a1agrawal': 6,
#  'a1ganesa': 1,
#  'a1mishra': 6,
#  'a1ye': 7,
#  'a2akbari': 7,
#  'a2ma': 7,
#  'a2vazque': 1,
#  'a3chao': 6,
#  'aaboushaaban': 2,
#  'aacameron': 7,
#  'aalghazouli': 1,
#  'aapiado': 7,
#  'aaverbuj': 6,
#  'ababoescu': 7,
#  'aborjasquintanilla': 3,
#  'acalza': 7,
#  'accalibuso': 7,
#  'achavarria': 7,
#  'achowdhry': 2,
#  'acrawley': 7,
#  'adagrawal': 7,
#  'adarun': 7,
#  'adevineni': 6,
#  'ahensel': 6,
#  'ahvu': 6,
#  'ajayamohan': 4,
#  'ajiang': 3,
#  'ajohari': 1,
#  'ajuljulian': 6,
#  'ajvalencia': 7,
#  'akamra': 1,
#  'akgoswam': 7,
#  'aklinefelter': 7,
#  'akn022': 7,
#  'akunitad': 7,
#  'alxiao': 7,
#  'alz007': 7,
#  'amasek': 1,
#  'amathi': 3,
#  'amkao': 7,
#  'amorris': 2,
#  'anag': 1,
#  'anarasimhan': 1,
#  'andsouza': 2,
#  'anprasad': 6,
#  'anslyker': 7,
#  'ant034': 1,
#  'antseng': 4,
#  'anw010': 6,
#  'anwen': 6,
#  'apimple': 6,
#  'apremkumar': 7,
#  'apurohit': 4,
#  'arajiv': 3,
#  'arakha': 7,
#  'arasin': 2,
#  'aravishankar': 7,
#  'arkonnova': 7,
#  'arobertson': 4,
#  'arshukla': 1,
#  'asagundo': 6,
#  'asierra': 7,
#  'asmithwick': 7,
#  'asonti': 5,
#  'asraj': 6,
#  'asubbarao': 2,
#  'aujung': 6,
#  'avasanth': 1,
#  'awrussell': 7,
#  'azc001': 7,
#  'azhuchou': 7,
#  'b2zhu': 7,
#  'bbeeson': 3,
#  'bbudiputra': 7,
#  'bbxia': 7,
#  'bdioneda': 3,
#  'bdubois': 7,
#  'bfernandez': 7,
#  'bfune': 6,
#  'bhacia': 2,
#  'bigao': 7,
#  'bjackola': 3,
#  'bnl002': 5,
#  'bnle': 6,
#  'bojia': 7,
#  'bop002': 4,
#  'boz002': 7,
#  'bquijada': 7,
#  'brchu': 2,
#  'brzhu': 7,
#  'bschan': 7,
#  'bsepulve': 6,
#  'bthome': 7,
#  'bzou': 7,
#  'c1shu': 6,
#  'c4yan': 7,
#  'c5jiang': 7,
#  'c5ni': 7,
#  'c8phan': 3,
#  'cas007': 6,
#  'ccl011': 7,
#  'cerpeldi': 2,
#  'chao': 6,
#  'chc057': 7,
#  'chd004': 6,
#  'chl125': 7,
#  'chl135': 6,
#  'choman': 2,
#  'cht019': 7,
#  'ckavanagh': 4,
#  'cktan': 7,
#  'crishi': 1,
#  'ctevans': 6,
#  'ctomlin': 6,
#  'ctwalsh': 7,
#  'czakkour': 6,
#  'd3kong': 1,
#  'd5wu': 7,
#  'daw010': 7,
#  'dcarrion': 2,
#  'ddonskoy': 7,
#  'dekhan': 5,
#  'del021': 7,
#  'dfeliton': 7,
#  'dgines': 3,
#  'dhl001': 7,
#  'dithomas': 7,
#  'dkn003': 7,
#  'dktran': 7,
#  'dnkim': 1,
#  'drovira': 7,
#  'dshi': 7,
#  'dshin': 4,
#  'dyonemura': 2,
#  'e2sun': 6,
#  'e4zhou': 7,
#  'e7rodrig': 2,
#  'e7song': 7,
#  'e8garcia': 1,
#  'eag002': 7,
#  'ealopez': 7,
#  'efg004': 6,
#  'ehcho': 7,
#  'eheffernan': 5,
#  'ejao': 6,
#  'ejlau': 6,
#  'ejxiong': 4,
#  'ekakarla': 1,
#  'emiranda': 6,
#  'emn005': 1,
#  'enchin': 6,
#  'eplong': 7,
#  'erk004': 7,
#  'ervu': 7,
#  'esharkov': 4,
#  'estratford': 3,
#  'etl003': 7,
#  'etwaters': 5,
#  'evchan': 3,
#  'eyenikomshian': 3,
#  'eyk005': 6,
#  'ezdeng': 6,
#  'f3li': 7,
#  'fdong': 6,
#  'fenriquez': 7,
#  'fepeng': 7,
#  'fetang': 7,
#  'fjiang': 7,
#  'fpeng': 5,
#  'gbutters': 7,
#  'gdietz': 7,
#  'gfeghali': 5,
#  'gihoang': 7,
#  'gjchen': 7,
#  'gjl001': 7,
#  'gkweon': 1,
#  'gluengowoods': 3,
#  'gmoreau': 7,
#  'gpong': 7,
#  'gprabhak': 6,
#  'groberg': 7,
#  'grquach': 7,
#  'gsandhu': 7,
#  'h2choi': 7,
#  'h3cai': 7,
#  'h6fu': 6,
#  'h9cheng': 1,
#  'hashcroft': 3,
#  'haw086': 6,
#  'haw189': 7,
#  'haz042': 7,
#  'hazou': 7,
#  'hbrownell': 1,
#  'hdehaini': 2,
#  'hduong': 1,
#  'hey001': 2,
#  'hgurusan': 6,
#  'hhai': 7,
#  'hhshin': 3,
#  'hic001': 7,
#  'hohu': 5,
#  'hojia': 7,
#  'hsflores': 2,
#  'hsy002': 7,
#  'htonnu': 6,
#  'htse': 4,
#  'hushan': 5,
#  'huy005': 7,
#  'hvphan': 2,
#  'hwk001': 7,
#  'hykung': 7,
#  'i1cheng': 7,
#  'iachai': 7,
#  'ihamid': 1,
#  'iozekici': 6,
#  'ipendlet': 2,
#  'iroque': 6,
#  'ivenzon': 7,
#  'j1ouyang': 6,
#  'j1tsai': 5,
#  'j2lyu': 7,
#  'j3ko': 4,
#  'j5dai': 4,
#  'j8cao': 6,
#  'j8ramos': 6,
#  'jabondano': 6,
#  'jac018': 7,
#  'jah003': 7,
#  'jakwak': 7,
#  'jal039': 6,
#  'jalinas': 3,
#  'janayagarcia': 7,
#  'jariss': 4,
#  'jartley': 7,
#  'jasabio': 6,
#  'jazheng': 7,
#  'jcc002': 1,
#  'jchowe': 4,
#  'jdegraaf': 7,
#  'jedang': 7,
#  'jefung': 7,
#  'jevalle': 7,
#  'jey013': 6,
#  'jgamm': 7,
#  'jgow': 6,
#  'jhw009': 7,
#  'jig015': 6,
#  'jig036': 1,
#  'jih063': 1,
#  'jih101': 6,
#  'jil237': 7,
#  'jil249': 7,
#  'jit011': 7,
#  'jiw118': 7,
#  'jiz145': 7,
#  'jiz147': 7,
#  'jjl027': 2,
#  'jjwu': 5,
#  'jkaminsky': 7,
#  'jkarim': 7,
#  'jkl015': 7,
#  'jlazcano': 1,
#  'jnishi': 7,
#  'joy005': 4,
#  'jpon': 7,
#  'jqthai': 4,
#  'jrarreguin': 7,
#  'jrjimenez': 7,
#  'jshyu': 7,
#  'jsimpauco': 7,
#  'json': 7,
#  'jstreett': 2,
#  'jtanurdjaja': 7,
#  'jtcastillo': 7,
#  'jtello': 7,
#  'jtutak': 2,
#  'juk019': 6,
#  'jul050': 7,
#  'jum004': 7,
#  'jup006': 7,
#  'juw024': 5,
#  'juw050': 7,
#  'jweconomy': 2,
#  'jyangari': 7,
#  'jyip': 6,
#  'jyl013': 4,
#  'jyli': 7,
#  'jyyip': 7,
#  'jzwu': 7,
#  'k1chang': 6,
#  'k3zhang': 7,
#  'k4do': 6,
#  'k6ma': 7,
#  'k6qin': 7,
#  'k9kang': 7,
#  'k9zhou': 7,
#  'kal030': 7,
#  'kan005': 6,
#  'kan024': 7,
#  'karaj': 1,
#  'karcos': 6,
#  'kdgao': 1,
#  'keh004': 6,
#  'kekang': 7,
#  'kew027': 6,
#  'kewoo': 7,
#  'key009': 7,
#  'kfleisch': 7,
#  'kggarcia': 7,
#  'kgugnani': 5,
#  'kham': 1,
#  'khho': 5,
#  'khidayat': 7,
#  'khn009': 2,
#  'khpark': 5,
#  'khw001': 7,
#  'kjchou': 2,
#  'kjk004': 6,
#  'kjsong': 7,
#  'kkla': 7,
#  'kkray': 3,
#  'kku': 7,
#  'knelakon': 5,
#  'kpansuri': 1,
#  'kponce': 7,
#  'kpstern': 7,
#  'kqu': 3,
#  'kseely': 4,
#  'ktn013': 5,
#  'kuw010': 7,
#  'kvankirk': 6,
#  'kwchin': 7,
#  'kyl011': 4,
#  'l1zhuo': 3,
#  'l3wang': 7,
#  'lazhou': 7,
#  'lballest': 7,
#  'ldai': 7,
#  'ldwight': 4,
#  'lez002': 1,
#  'lfasting': 6,
#  'lgan': 7,
#  'lgasser': 7,
#  'licarrillo': 5,
#  'lil010': 3,
#  'lim007': 1,
#  'liz009': 7,
#  'liz035': 5,
#  'lmho': 3,
#  'lnhernan': 1,
#  'lsfleig': 7,
#  'ltn011': 2,
#  'luz010': 7,
#  'lyazouri': 4,
#  'm3shen': 3,
#  'm5lee': 1,
#  'madebiyi': 4,
#  'mag026': 1,
#  'mamontano': 7,
#  'mamorera': 1,
#  'mas026': 7,
#  'max003': 7,
#  'mbach': 7,
#  'mbuan': 1,
#  'mdimitropoulouka': 7,
#  'mdkawakami': 7,
#  'mdulansk': 1,
#  'meburrows': 7,
#  'mec005': 6,
#  'mec009': 6,
#  'mesantos': 2,
#  'mgliu': 7,
#  'mgujavarthi': 6,
#  'mhle': 7,
#  'mic035': 7,
#  'mik023': 2,
#  'mil049': 7,
#  'mis005': 4,
#  'mis008': 7,
#  'miso': 7,
#  'miz030': 7,
#  'mjtang': 7,
#  'mkhawaja': 4,
#  'mmckenziegarand': 7,
#  'mmdavid': 5,
#  'mmelkony': 7,
#  'mml002': 7,
#  'mmuruganandam': 7,
#  'mndiaz': 6,
#  'mnleong': 7,
#  'mntan': 7,
#  'molmedo': 1,
#  'mrenteri': 2,
#  'msk001': 7,
#  'mslai': 7,
#  'mszeto': 7,
#  'mwelsome': 7,
#  'mwidyadh': 6,
#  'mxian': 6,
#  'n1rashid': 7,
#  'n1shinde': 7,
#  'n2lam': 7,
#  'naalami': 2,
#  'nal008': 6,
#  'narumugam': 7,
#  'nbajaj': 6,
#  'nboloori': 2,
#  'nccronin': 6,
#  'nchepuri': 7,
#  'ncrawley': 7,
#  'nekeodar': 1,
#  'nghosh': 6,
#  'niquach': 4,
#  'nmarthen': 3,
#  'nmummala': 7,
#  'nokerendian': 7,
#  'nol001': 7,
#  'npantfoerder': 3,
#  'npareddy': 1,
#  'nrepetti': 6,
#  'ntchung': 7,
#  'nthiyagarajan': 6,
#  'ntrejo': 3,
#  'nwzhang': 7,
#  'obychenkov': 7,
#  'okhalil': 1,
#  'otang': 7,
#  'ouli': 7,
#  'p1chiang': 6,
#  'p1nair': 7,
#  'p3xu': 6,
#  'pgaikwad': 6,
#  'pgaudet': 7,
#  'phelcl': 7,
#  'piw001': 7,
#  'pjtran': 6,
#  'pkatukojwala': 5,
#  'pking': 7,
#  'pklam': 1,
#  'pmondrag': 7,
#  'pprabhu': 5,
#  'pputtapa': 1,
#  'prebala': 7,
#  'prkhanna': 6,
#  'pssanchez': 2,
#  'pviwatkurkul': 7,
#  'pyhui': 3,
#  'q7hu': 7,
#  'q8chen': 7,
#  'qhui': 4,
#  'qihou': 7,
#  'qnhoang': 3,
#  'r2zhu': 7,
#  'r3xiao': 6,
#  'r6sanche': 5,
#  'r6yang': 7,
#  'r8huang': 7,
#  'rbaldoz': 4,
#  'rdwong': 6,
#  'rhli': 7,
#  'rhlin': 7,
#  'rin002': 7,
#  'rkant': 1,
#  'rlizaranmolina': 6,
#  'rmali': 7,
#  'rmeserve': 6,
#  'rmn001': 7,
#  'roh002': 7,
#  'rojiang': 7,
#  'rpaquia': 3,
#  'rpenchala': 1,
#  'rpeng': 1,
#  'rriosram': 7,
#  'rsunku': 2,
#  'rtay': 5,
#  'rul020': 7,
#  'rusmanova': 7,
#  'ruw008': 7,
#  'ruzhong': 7,
#  's1rai': 7,
#  's2malik': 6,
#  's4min': 7,
#  's5sharma': 6,
#  's7liang': 7,
#  'sal038': 4,
#  'saliang': 5,
#  'samann': 7,
#  'sanarayanan': 7,
#  'sat001': 4,
#  'sbnorthrop': 7,
#  'sboddy': 6,
#  'sbramire': 4,
#  'sdsteven': 2,
#  'senkhjargal': 7,
#  'sevtimova': 7,
#  'sfinch': 5,
#  'sfrianeza': 7,
#  'sgaribayzaguilan': 1,
#  'sgoh': 5,
#  'sgong': 7,
#  'shl127': 7,
#  'shmusini': 1,
#  'shsam': 7,
#  'shw050': 7,
#  'shz040': 2,
#  'shz054': 4,
#  'sic018': 7,
#  'siw031': 7,
#  'sjc003': 4,
#  'smai': 7,
#  'smejia': 7,
#  'smkim': 5,
#  'snguyenphuoc': 7,
#  'spamudji': 3,
#  'spital': 6,
#  'spuri': 7,
#  'sragarwa': 7,
#  'srote': 1,
#  'ssahar': 7,
#  'ssantacruzibarra': 3,
#  'sschlagheck': 6,
#  'stalanki': 7,
#  'stchavez': 6,
#  'suaye': 7,
#  'svaldimarsdottir': 7,
#  'svallumchetla': 7,
#  'svirk': 7,
#  'swmenon': 3,
#  'sxluong': 6,
#  't8li': 7,
#  't8wu': 7,
#  'tan003': 7,
#  'tbmai': 7,
#  'tchui': 1,
#  'tfoster': 7,
#  'tgibbs': 1,
#  'thw001': 7,
#  'tibao': 7,
#  'tin003': 5,
#  'tithai': 7,
#  'tjoel': 7,
#  'tjshin': 7,
#  'tkawser': 2,
#  'tkk002': 7,
#  'tkn003': 7,
#  'tll001': 2,
#  'ton002': 7,
#  'tpagela': 7,
#  'trtruong': 7,
#  'trucker': 4,
#  'trvu': 5,
#  'tshaikh': 3,
#  'tsharifi': 6,
#  'tsugita': 7,
#  'ttp007': 4,
#  'tyyu': 7,
#  'unaik': 7,
#  'v1prado': 3,
#  'v7patel': 7,
#  'v8gonzal': 7,
#  'v9wong': 6,
#  'vhasthi': 4,
#  'vhinds': 1,
#  'vhu': 6,
#  'vihuang': 7,
#  'vkwan': 7,
#  'vlohia': 6,
#  'vswamy': 4,
#  'w9chan': 7,
#  'w9lin': 2,
#  'wcw003': 1,
#  'wej002': 6,
#  'wsupian': 7,
#  'wuli': 6,
#  'x1shu': 5,
#  'x7wen': 3,
#  'xif001': 7,
#  'xig001': 7,
#  'xig003': 5,
#  'xih035': 7,
#  'xiy005': 7,
#  'xuh011': 7,
#  'xushi': 7,
#  'y2bu': 4,
#  'y2lai': 1,
#  'y4zhong': 6,
#  'y6tang': 3,
#  'y7qin': 7,
#  'yag007': 7,
#  'yamazaheri': 5,
#  'yax016': 7,
#  'yaxiao': 5,
#  'yay019': 6,
#  'yechoi': 5,
#  'yek003': 5,
#  'yic057': 7,
#  'yic075': 7,
#  'yic079': 7,
#  'yih045': 4,
#  'yilou': 7,
#  'yiw072': 4,
#  'yiz029': 7,
#  'yiz036': 4,
#  'yiz123': 7,
#  'yuhung': 4,
#  'yuj036': 7,
#  'yul196': 4,
#  'yut009': 3,
#  'yuw096': 7,
#  'yuw135': 7,
#  'yuz159': 7,
#  'yyanagawa': 5,
#  'z2yu': 7,
#  'z4cai': 6,
#  'z4han': 7,
#  'z4wan': 1,
#  'z5wei': 4,
#  'z7peng': 7,
#  'z8yuan': 7,
#  'zakhater': 7,
#  'zamahmood': 1,
#  'zedu': 7,
#  'zhh022': 1,
#  'zhx003': 7,
#  'zhz044': 1,
#  'zhz084': 1,
#  'zil089': 7,
#  'zil090': 6,
#  'ziqiu': 7,
#  'ziz057': 7,
#  'zlim': 7,
#  'zpun': 6}

# %%
def publish_scores(course_id, assignment_id, student_ids, students_with_weeks_completed, api_url, api_key, score):
    headers = {"Authorization": f"Bearer {api_key}"}

    for login_id, weeks_completed in students_with_weeks_completed.items():
        student_id = student_ids.get(login_id)
        
        # Publish score only if the student has completed all 7 weeks.
        if weeks_completed == 7:
            endpoint = f"{api_url}/api/v1/courses/{course_id}/assignments/{assignment_id}/submissions/{student_id}"
            payload = {"submission": {"posted_grade": score}}
            response = requests.put(endpoint, headers=headers, json=payload)

            if response.status_code == 200:
                print(f"Score {score} published for student ID {student_id} (login ID: {login_id}).")
            else:
                print(f"Failed to publish score for student ID {student_id} (login ID: {login_id}): {response.text}")

# %%
publish_scores(COURSE_ID, ASSIGNMENT_ID, student_ids, students_with_weeks_completed, API_URL, API_KEY, SCORE)
# Out:
# Score 0.5 published for student ID 107372 (login ID: a1ye).
# Score 0.5 published for student ID 132045 (login ID: a2akbari).
# Score 0.5 published for student ID 133124 (login ID: a2ma).
# Score 0.5 published for student ID 134170 (login ID: aacameron).
# Score 0.5 published for student ID 108717 (login ID: aapiado).
# Score 0.5 published for student ID 170353 (login ID: ababoescu).
# Score 0.5 published for student ID 131533 (login ID: acalza).
# Score 0.5 published for student ID 129102 (login ID: accalibuso).
# Score 0.5 published for student ID 132115 (login ID: achavarria).
# Score 0.5 published for student ID 141212 (login ID: acrawley).
# Score 0.5 published for student ID 137772 (login ID: adagrawal).
# Score 0.5 published for student ID 132164 (login ID: adarun).
# Score 0.5 published for student ID 130681 (login ID: ajvalencia).
# Score 0.5 published for student ID 99998 (login ID: akgoswam).
# Score 0.5 published for student ID 127254 (login ID: aklinefelter).
# Score 0.5 published for student ID 4273 (login ID: akn022).
# Score 0.5 published for student ID 103910 (login ID: akunitad).
# Score 0.5 published for student ID 133096 (login ID: alxiao).
# Score 0.5 published for student ID 165074 (login ID: alz007).
# Score 0.5 published for student ID 129728 (login ID: amkao).
# Score 0.5 published for student ID 128257 (login ID: anslyker).
# Score 0.5 published for student ID 135797 (login ID: apremkumar).
# Score 0.5 published for student ID 169157 (login ID: arakha).
# Score 0.5 published for student ID 132074 (login ID: aravishankar).
# Score 0.5 published for student ID 130232 (login ID: arkonnova).
# Score 0.5 published for student ID 105137 (login ID: asierra).
# Score 0.5 published for student ID 160049 (login ID: asmithwick).
# Score 0.5 published for student ID 134387 (login ID: awrussell).
# Score 0.5 published for student ID 140274 (login ID: azc001).
# Score 0.5 published for student ID 97046 (login ID: azhuchou).
# Score 0.5 published for student ID 129500 (login ID: b2zhu).
# Score 0.5 published for student ID 139975 (login ID: bbudiputra).
# Score 0.5 published for student ID 130120 (login ID: bbxia).
# Score 0.5 published for student ID 166952 (login ID: bdubois).
# Score 0.5 published for student ID 108648 (login ID: bfernandez).
# Score 0.5 published for student ID 131549 (login ID: bigao).
# Score 0.5 published for student ID 130053 (login ID: bojia).
# Score 0.5 published for student ID 138620 (login ID: boz002).
# Score 0.5 published for student ID 127412 (login ID: bquijada).
# Score 0.5 published for student ID 133015 (login ID: brzhu).
# Score 0.5 published for student ID 103400 (login ID: bschan).
# Score 0.5 published for student ID 107802 (login ID: bthome).
# Score 0.5 published for student ID 105565 (login ID: bzou).
# Score 0.5 published for student ID 99288 (login ID: c4yan).
# Score 0.5 published for student ID 132637 (login ID: c5jiang).
# Score 0.5 published for student ID 47697 (login ID: c5ni).
# Score 0.5 published for student ID 132220 (login ID: ccl011).
# Score 0.5 published for student ID 132491 (login ID: chc057).
# Score 0.5 published for student ID 128347 (login ID: chl125).
# Score 0.5 published for student ID 170169 (login ID: cht019).
# Score 0.5 published for student ID 30341 (login ID: cktan).
# Score 0.5 published for student ID 136785 (login ID: ctwalsh).
# Score 0.5 published for student ID 96248 (login ID: d5wu).
# Score 0.5 published for student ID 136924 (login ID: daw010).
# Score 0.5 published for student ID 135973 (login ID: ddonskoy).
# Score 0.5 published for student ID 157393 (login ID: del021).
# Score 0.5 published for student ID 129335 (login ID: dfeliton).
# Score 0.5 published for student ID 132117 (login ID: dhl001).
# Score 0.5 published for student ID 171542 (login ID: dithomas).
# Score 0.5 published for student ID 135702 (login ID: dkn003).
# Score 0.5 published for student ID 108509 (login ID: dktran).
# Score 0.5 published for student ID 107161 (login ID: drovira).
# Score 0.5 published for student ID 101203 (login ID: dshi).
# Score 0.5 published for student ID 171822 (login ID: e4zhou).
# Score 0.5 published for student ID 136784 (login ID: e7song).
# Score 0.5 published for student ID 133648 (login ID: eag002).
# Score 0.5 published for student ID 131585 (login ID: ealopez).
# Score 0.5 published for student ID 132330 (login ID: ehcho).
# Score 0.5 published for student ID 130763 (login ID: eplong).
# Score 0.5 published for student ID 131083 (login ID: erk004).
# Score 0.5 published for student ID 168424 (login ID: ervu).
# Score 0.5 published for student ID 134761 (login ID: etl003).
# Score 0.5 published for student ID 100900 (login ID: f3li).
# Score 0.5 published for student ID 166981 (login ID: fenriquez).
# Score 0.5 published for student ID 130719 (login ID: fepeng).
# Score 0.5 published for student ID 129664 (login ID: fetang).
# Score 0.5 published for student ID 129312 (login ID: fjiang).
# Score 0.5 published for student ID 135159 (login ID: gbutters).
# Score 0.5 published for student ID 105246 (login ID: gdietz).
# Score 0.5 published for student ID 166905 (login ID: gihoang).
# Score 0.5 published for student ID 101556 (login ID: gjchen).
# Score 0.5 published for student ID 131066 (login ID: gjl001).
# Score 0.5 published for student ID 92397 (login ID: gmoreau).
# Score 0.5 published for student ID 166554 (login ID: gpong).
# Score 0.5 published for student ID 131608 (login ID: groberg).
# Score 0.5 published for student ID 133551 (login ID: grquach).
# Score 0.5 published for student ID 135425 (login ID: gsandhu).
# Score 0.5 published for student ID 15469 (login ID: h2choi).
# Score 0.5 published for student ID 131086 (login ID: h3cai).
# Score 0.5 published for student ID 10097 (login ID: haw189).
# Score 0.5 published for student ID 103047 (login ID: haz042).
# Score 0.5 published for student ID 127805 (login ID: hazou).
# Score 0.5 published for student ID 168375 (login ID: hhai).
# Score 0.5 published for student ID 162694 (login ID: hic001).
# Score 0.5 published for student ID 168159 (login ID: hojia).
# Score 0.5 published for student ID 170865 (login ID: hsy002).
# Score 0.5 published for student ID 128795 (login ID: huy005).
# Score 0.5 published for student ID 99704 (login ID: hwk001).
# Score 0.5 published for student ID 168962 (login ID: hykung).
# Score 0.5 published for student ID 163522 (login ID: i1cheng).
# Score 0.5 published for student ID 107324 (login ID: iachai).
# Score 0.5 published for student ID 170550 (login ID: ivenzon).
# Score 0.5 published for student ID 95525 (login ID: j2lyu).
# Score 0.5 published for student ID 130313 (login ID: jac018).
# Score 0.5 published for student ID 100114 (login ID: jah003).
# Score 0.5 published for student ID 16293 (login ID: jakwak).
# Score 0.5 published for student ID 127201 (login ID: janayagarcia).
# Score 0.5 published for student ID 170159 (login ID: jartley).
# Score 0.5 published for student ID 99571 (login ID: jazheng).
# Score 0.5 published for student ID 141132 (login ID: jdegraaf).
# Score 0.5 published for student ID 133457 (login ID: jedang).
# Score 0.5 published for student ID 136551 (login ID: jefung).
# Score 0.5 published for student ID 99726 (login ID: jevalle).
# Score 0.5 published for student ID 136823 (login ID: jgamm).
# Score 0.5 published for student ID 139261 (login ID: jhw009).
# Score 0.5 published for student ID 130300 (login ID: jil237).
# Score 0.5 published for student ID 136582 (login ID: jil249).
# Score 0.5 published for student ID 170322 (login ID: jit011).
# Score 0.5 published for student ID 133594 (login ID: jiw118).
# Score 0.5 published for student ID 127808 (login ID: jiz145).
# Score 0.5 published for student ID 129253 (login ID: jiz147).
# Score 0.5 published for student ID 135379 (login ID: jkaminsky).
# Score 0.5 published for student ID 171056 (login ID: jkarim).
# Score 0.5 published for student ID 170594 (login ID: jkl015).
# Score 0.5 published for student ID 104244 (login ID: jnishi).
# Score 0.5 published for student ID 100011 (login ID: jpon).
# Score 0.5 published for student ID 135193 (login ID: jrarreguin).
# Score 0.5 published for student ID 136152 (login ID: jrjimenez).
# Score 0.5 published for student ID 136075 (login ID: jshyu).
# Score 0.5 published for student ID 130660 (login ID: jsimpauco).
# Score 0.5 published for student ID 95295 (login ID: json).
# Score 0.5 published for student ID 132129 (login ID: jtanurdjaja).
# Score 0.5 published for student ID 132711 (login ID: jtcastillo).
# Score 0.5 published for student ID 136555 (login ID: jtello).
# Score 0.5 published for student ID 106002 (login ID: jul050).
# Score 0.5 published for student ID 134507 (login ID: jum004).
# Score 0.5 published for student ID 58473 (login ID: jup006).
# Score 0.5 published for student ID 167667 (login ID: juw050).
# Score 0.5 published for student ID 129582 (login ID: jyangari).
# Score 0.5 published for student ID 94437 (login ID: jyli).
# Score 0.5 published for student ID 101860 (login ID: jyyip).
# Score 0.5 published for student ID 95712 (login ID: jzwu).
# Score 0.5 published for student ID 34465 (login ID: k3zhang).
# Score 0.5 published for student ID 98047 (login ID: k6ma).
# Score 0.5 published for student ID 63257 (login ID: k6qin).
# Score 0.5 published for student ID 168471 (login ID: k9kang).
# Score 0.5 published for student ID 129852 (login ID: k9zhou).
# Score 0.5 published for student ID 139361 (login ID: kal030).
# Score 0.5 published for student ID 170853 (login ID: kan024).
# Score 0.5 published for student ID 139467 (login ID: kekang).
# Score 0.5 published for student ID 136387 (login ID: kewoo).
# Score 0.5 published for student ID 132152 (login ID: key009).
# Score 0.5 published for student ID 101491 (login ID: kfleisch).
# Score 0.5 published for student ID 129735 (login ID: kggarcia).
# Score 0.5 published for student ID 169710 (login ID: khidayat).
# Score 0.5 published for student ID 132525 (login ID: khw001).
# Score 0.5 published for student ID 140061 (login ID: kjsong).
# Score 0.5 published for student ID 132533 (login ID: kkla).
# Score 0.5 published for student ID 134050 (login ID: kku).
# Score 0.5 published for student ID 132502 (login ID: kponce).
# Score 0.5 published for student ID 104281 (login ID: kpstern).
# Score 0.5 published for student ID 129236 (login ID: kuw010).
# Score 0.5 published for student ID 107369 (login ID: kwchin).
# Score 0.5 published for student ID 96202 (login ID: l3wang).
# Score 0.5 published for student ID 102380 (login ID: lazhou).
# Score 0.5 published for student ID 96800 (login ID: lballest).
# Score 0.5 published for student ID 95488 (login ID: ldai).
# Score 0.5 published for student ID 135320 (login ID: lgan).
# Score 0.5 published for student ID 108020 (login ID: lgasser).
# Score 0.5 published for student ID 96199 (login ID: liz009).
# Score 0.5 published for student ID 134432 (login ID: lsfleig).
# Score 0.5 published for student ID 127844 (login ID: luz010).
# Score 0.5 published for student ID 133108 (login ID: mamontano).
# Score 0.5 published for student ID 169558 (login ID: mas026).
# Score 0.5 published for student ID 99841 (login ID: max003).
# Score 0.5 published for student ID 136327 (login ID: mbach).
# Score 0.5 published for student ID 106164 (login ID: mdimitropoulouka).
# Score 0.5 published for student ID 160810 (login ID: mdkawakami).
# Score 0.5 published for student ID 124994 (login ID: meburrows).
# Score 0.5 published for student ID 138671 (login ID: mgliu).
# Score 0.5 published for student ID 133030 (login ID: mhle).
# Score 0.5 published for student ID 170684 (login ID: mic035).
# Score 0.5 published for student ID 127861 (login ID: mil049).
# Score 0.5 published for student ID 168675 (login ID: mis008).
# Score 0.5 published for student ID 168889 (login ID: miso).
# Score 0.5 published for student ID 166846 (login ID: miz030).
# Score 0.5 published for student ID 136062 (login ID: mjtang).
# Score 0.5 published for student ID 168298 (login ID: mmckenziegarand).
# Score 0.5 published for student ID 102965 (login ID: mmelkony).
# Score 0.5 published for student ID 132734 (login ID: mml002).
# Score 0.5 published for student ID 134467 (login ID: mmuruganandam).
# Score 0.5 published for student ID 129309 (login ID: mnleong).
# Score 0.5 published for student ID 102013 (login ID: mntan).
# Score 0.5 published for student ID 77671 (login ID: msk001).
# Score 0.5 published for student ID 131512 (login ID: mslai).
# Score 0.5 published for student ID 133026 (login ID: mszeto).
# Score 0.5 published for student ID 95013 (login ID: mwelsome).
# Score 0.5 published for student ID 127796 (login ID: n1rashid).
# Score 0.5 published for student ID 169380 (login ID: n1shinde).
# Score 0.5 published for student ID 95531 (login ID: n2lam).
# Score 0.5 published for student ID 128169 (login ID: narumugam).
# Score 0.5 published for student ID 129432 (login ID: nchepuri).
# Score 0.5 published for student ID 141509 (login ID: ncrawley).
# Score 0.5 published for student ID 94372 (login ID: nmummala).
# Score 0.5 published for student ID 163873 (login ID: nokerendian).
# Score 0.5 published for student ID 132979 (login ID: nol001).
# Score 0.5 published for student ID 134501 (login ID: ntchung).
# Score 0.5 published for student ID 132703 (login ID: nwzhang).
# Score 0.5 published for student ID 164044 (login ID: obychenkov).
# Score 0.5 published for student ID 126395 (login ID: otang).
# Score 0.5 published for student ID 130912 (login ID: ouli).
# Score 0.5 published for student ID 137768 (login ID: p1nair).
# Score 0.5 published for student ID 169328 (login ID: pgaudet).
# Score 0.5 published for student ID 96271 (login ID: phelcl).
# Score 0.5 published for student ID 140172 (login ID: piw001).
# Score 0.5 published for student ID 129223 (login ID: pking).
# Score 0.5 published for student ID 102711 (login ID: pmondrag).
# Score 0.5 published for student ID 133337 (login ID: prebala).
# Score 0.5 published for student ID 132673 (login ID: pviwatkurkul).
# Score 0.5 published for student ID 134529 (login ID: q7hu).
# Score 0.5 published for student ID 98371 (login ID: q8chen).
# Score 0.5 published for student ID 102402 (login ID: qihou).
# Score 0.5 published for student ID 126239 (login ID: r2zhu).
# Score 0.5 published for student ID 96899 (login ID: r6yang).
# Score 0.5 published for student ID 100644 (login ID: r8huang).
# Score 0.5 published for student ID 103513 (login ID: rhli).
# Score 0.5 published for student ID 97257 (login ID: rhlin).
# Score 0.5 published for student ID 167989 (login ID: rin002).
# Score 0.5 published for student ID 101023 (login ID: rmali).
# Score 0.5 published for student ID 135690 (login ID: rmn001).
# Score 0.5 published for student ID 130323 (login ID: roh002).
# Score 0.5 published for student ID 138145 (login ID: rojiang).
# Score 0.5 published for student ID 16685 (login ID: rriosram).
# Score 0.5 published for student ID 128339 (login ID: rul020).
# Score 0.5 published for student ID 138528 (login ID: rusmanova).
# Score 0.5 published for student ID 98708 (login ID: ruw008).
# Score 0.5 published for student ID 130569 (login ID: ruzhong).
# Score 0.5 published for student ID 97451 (login ID: s1rai).
# Score 0.5 published for student ID 136797 (login ID: s4min).
# Score 0.5 published for student ID 127779 (login ID: s7liang).
# Score 0.5 published for student ID 168979 (login ID: samann).
# Score 0.5 published for student ID 131668 (login ID: sanarayanan).
# Score 0.5 published for student ID 124614 (login ID: sbnorthrop).
# Score 0.5 published for student ID 168007 (login ID: senkhjargal).
# Score 0.5 published for student ID 134831 (login ID: sevtimova).
# Score 0.5 published for student ID 170014 (login ID: sfrianeza).
# Score 0.5 published for student ID 129503 (login ID: sgong).
# Score 0.5 published for student ID 170346 (login ID: shl127).
# Score 0.5 published for student ID 138732 (login ID: shsam).
# Score 0.5 published for student ID 102630 (login ID: shw050).
# Score 0.5 published for student ID 132427 (login ID: sic018).
# Score 0.5 published for student ID 133412 (login ID: siw031).
# Score 0.5 published for student ID 97892 (login ID: smai).
# Score 0.5 published for student ID 107367 (login ID: smejia).
# Score 0.5 published for student ID 106259 (login ID: snguyenphuoc).
# Score 0.5 published for student ID 107429 (login ID: spuri).
# Score 0.5 published for student ID 95700 (login ID: sragarwa).
# Score 0.5 published for student ID 169974 (login ID: ssahar).
# Score 0.5 published for student ID 103007 (login ID: stalanki).
# Score 0.5 published for student ID 170628 (login ID: suaye).
# Score 0.5 published for student ID 166937 (login ID: svaldimarsdottir).
# Score 0.5 published for student ID 133913 (login ID: svallumchetla).
# Score 0.5 published for student ID 99247 (login ID: svirk).
# Score 0.5 published for student ID 95984 (login ID: t8li).
# Score 0.5 published for student ID 100057 (login ID: t8wu).
# Score 0.5 published for student ID 103163 (login ID: tan003).
# Score 0.5 published for student ID 101569 (login ID: tbmai).
# Score 0.5 published for student ID 80996 (login ID: tfoster).
# Score 0.5 published for student ID 95906 (login ID: thw001).
# Score 0.5 published for student ID 126284 (login ID: tibao).
# Score 0.5 published for student ID 166891 (login ID: tithai).
# Score 0.5 published for student ID 104952 (login ID: tjoel).
# Score 0.5 published for student ID 136512 (login ID: tjshin).
# Score 0.5 published for student ID 171314 (login ID: tkk002).
# Score 0.5 published for student ID 133366 (login ID: tkn003).
# Score 0.5 published for student ID 128855 (login ID: ton002).
# Score 0.5 published for student ID 106148 (login ID: tpagela).
# Score 0.5 published for student ID 101983 (login ID: trtruong).
# Score 0.5 published for student ID 107961 (login ID: tsugita).
# Score 0.5 published for student ID 97235 (login ID: tyyu).
# Score 0.5 published for student ID 128282 (login ID: unaik).
# Score 0.5 published for student ID 133677 (login ID: v7patel).
# Score 0.5 published for student ID 102641 (login ID: v8gonzal).
# Score 0.5 published for student ID 141729 (login ID: vihuang).
# Score 0.5 published for student ID 135894 (login ID: vkwan).
# Score 0.5 published for student ID 169677 (login ID: w9chan).
# Score 0.5 published for student ID 133476 (login ID: wsupian).
# Score 0.5 published for student ID 131623 (login ID: xif001).
# Score 0.5 published for student ID 130702 (login ID: xig001).
# Score 0.5 published for student ID 132190 (login ID: xih035).
# Score 0.5 published for student ID 96286 (login ID: xiy005).
# Score 0.5 published for student ID 130264 (login ID: xuh011).
# Score 0.5 published for student ID 131007 (login ID: xushi).
# Score 0.5 published for student ID 95289 (login ID: y7qin).
# Score 0.5 published for student ID 136633 (login ID: yag007).
# Score 0.5 published for student ID 167961 (login ID: yax016).
# Score 0.5 published for student ID 103045 (login ID: yic057).
# Score 0.5 published for student ID 136562 (login ID: yic075).
# Score 0.5 published for student ID 140376 (login ID: yic079).
# Score 0.5 published for student ID 131104 (login ID: yilou).
# Score 0.5 published for student ID 95825 (login ID: yiz029).
# Score 0.5 published for student ID 104071 (login ID: yiz123).
# Score 0.5 published for student ID 128109 (login ID: yuj036).
# Score 0.5 published for student ID 97061 (login ID: yuw096).
# Score 0.5 published for student ID 129639 (login ID: yuw135).
# Score 0.5 published for student ID 127238 (login ID: yuz159).
# Score 0.5 published for student ID 91636 (login ID: z2yu).
# Score 0.5 published for student ID 107501 (login ID: z4han).
# Score 0.5 published for student ID 99613 (login ID: z7peng).
# Score 0.5 published for student ID 131877 (login ID: z8yuan).
# Score 0.5 published for student ID 170679 (login ID: zakhater).
# Score 0.5 published for student ID 97103 (login ID: zedu).
# Score 0.5 published for student ID 100748 (login ID: zhx003).
# Score 0.5 published for student ID 170870 (login ID: zil089).
# Score 0.5 published for student ID 134557 (login ID: ziqiu).
# Score 0.5 published for student ID 134859 (login ID: ziz057).
# Score 0.5 published for student ID 171627 (login ID: zlim).
