# %% [markdown]
# # Pre Course Survey Grading
#
# Author: Jason Chen
#
# 12/19/2023

# %% [markdown]
# ## How to use this script:
#
# 1. Go to Canvas, and generate the personal token, paste in the cell below.
#     - To do so, go to canvas.ucsd.edu, Account -> Settings -> Approved Integrations -> + New Access Token. Generate the access token, set the purpose and the expiration date, copy it.
# 2. Get the course id and assignment id, paste in the cell below.
# 3. Download the responses for Pre Course Survey as a csv file, upload it under the same directory as this script.
# 4. Paste the file path and the column name containing the email address in the cell below.
# 5. Run all the cells to publish score.

# %%
# Import packages needed:

import pandas as pd
import re
import requests
import csv
# Out:
# /home/grader-cogs108-02/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/grader-cogs108-02/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Initialize the variables:

# The URL of Canvas api, no need to change.
API_URL = "https://canvas.ucsd.edu"

# The access token for Canvas, need to generate on Canvas website and paste here.
API_KEY = "13171~m5qrWdND5GevNLg9WfeHzoY8pghyfZQWUT7mDo5G4npFEXvLucRuNChhzZ9HKxIG"

# The course id, can be found on Canvas.
COURSE_ID = "48733"

# The assignment id, can be found on Canvas.
ASSIGNMENT_ID = "693723"

# The score for the assignmnet Pre Course Survey, can be changed accordingly.
SCORE = 0.25

# The path of csv file contains responses for Pre Course Survey.
file_path = "COGS108 Precourse Student Survey (Fa23) (Responses) - Form Responses 1.csv"

# The column name that contains the emails.
column_name = "Email Address"

# %%
# Check for unique submission ids:
df = pd.read_csv(file_path)
len(df["Email Address"].unique())
# Out:
# 811

# %%
def get_student_ids(course_id, api_url, api_key):
    endpoint = f"{api_url}/api/v1/courses/{course_id}/users"
    headers = {"Authorization": f"Bearer {api_key}"}
    student_ids = {}

    while endpoint:
        response = requests.get(endpoint, headers=headers)
        if response.status_code == 200:
            users = response.json()
            for user in users:
                login_id = user.get('login_id')
                student_id = user.get('id')
                if login_id and student_id:
                    student_ids[login_id] = student_id

            links = response.links
            endpoint = links['next']['url'] if 'next' in links else None
        else:
            print("Failed to retrieve users: ", response.text)
            break

    return student_ids

# Usage

student_ids = get_student_ids(COURSE_ID, API_URL, API_KEY)

# %%
student_ids
# Out:
# {'jabondano': 170728,
#  'aaboushaaban': 167080,
#  'madebiyi': 169141,
#  'sragarwa': 95700,
#  'a6aggarw': 103380,
#  'adagrawal': 137772,
#  'a1agrawal': 133353,
#  'a2akbari': 132045,
#  'naalami': 9382,
#  'aalghazouli': 172661,
#  'rmali': 101023,
#  'jalinas': 167717,
#  'janayagarcia': 127201,
#  'aapiado': 108717,
#  'karcos': 130147,
#  'jariss': 168166,
#  'jrarreguin': 135193,
#  'jartley': 170159,
#  'narumugam': 128169,
#  'adarun': 132164,
#  'basami': 171360,
#  'hashcroft': 139799,
#  'aaverbuj': 167025,
#  'suaye': 170628,
#  'ababoescu': 170353,
#  'mbach': 136327,
#  'nbajaj': 100406,
#  'rbaldoz': 131582,
#  'lballest': 96800,
#  'jbanawa': 81727,
#  'dbansal': 159651,
#  'abanwait': 104930,
#  'tibao': 126284,
#  'gbarrosk': 97951,
#  'bbeeson': 108019,
#  'sboddy': 138313,
#  'nboloori': 95060,
#  'aborjasquintanilla': 107686,
#  'hbrownell': 107869,
#  'y2bu': 133383,
#  'mbuan': 100907,
#  'bbuckhan': 103343,
#  'bbudiputra': 139975,
#  'bjburke': 170924,
#  'meburrows': 124994,
#  'gbutters': 135159,
#  'obychenkov': 164044,
#  'h3cai': 131086,
#  'lecai': 97237,
#  'yic075': 136562,
#  'z4cai': 168309,
#  'accalibuso': 129102,
#  'acalza': 131533,
#  'aacameron': 134170,
#  'j8cao': 133538,
#  'licarrillo': 167122,
#  'dcarrion': 108027,
#  'jtcastillo': 132711,
#  'iachai': 107324,
#  'bschan': 103400,
#  'evchan': 133822,
#  'kec021': 133401,
#  'swchan': 130947,
#  'w9chan': 169677,
#  'k1chang': 99725,
#  'hic001': 162694,
#  'a3chao': 170488,
#  'achavarria': 132115,
#  'stchavez': 97137,
#  'mic035': 170684,
#  'azc001': 140274,
#  'q8chen': 98371,
#  'bhc001': 107245,
#  'mec005': 95952,
#  'gjchen': 101556,
#  'jac018': 130313,
#  'xic007': 54217,
#  'jpc005': 134294,
#  'jcc002': 133569,
#  'mec009': 168449,
#  'sjc003': 134113,
#  'yic079': 140376,
#  'yic057': 103045,
#  'sic018': 132427,
#  'chc057': 132491,
#  'h9cheng': 137113,
#  'i1cheng': 163522,
#  'nchepuri': 129432,
#  'p1chiang': 167935,
#  'enchin': 130151,
#  'kwchin': 107369,
#  'ehcho': 132330,
#  'h2choi': 15469,
#  'yechoi': 102793,
#  'kjchou': 134440,
#  'shchow': 94992,
#  'schowbey': 136274,
#  'achowdhry': 133494,
#  'brchu': 133630,
#  'ntchung': 134501,
#  'jmcole': 138819,
#  'tmcooper': 136945,
#  'acrawley': 141212,
#  'ncrawley': 141509,
#  'nccronin': 107444,
#  'j5dai': 136033,
#  'ldai': 95488,
#  'jedang': 133457,
#  'mmdavid': 134808,
#  'mdayanan': 92379,
#  'jdegraaf': 141132,
#  'hdehaini': 167691,
#  'eldelrosario': 135792,
#  'ezdeng': 169672,
#  'cdermanuelian': 107634,
#  'adevineni': 136736,
#  'fdiamond': 164723,
#  'mndiaz': 108721,
#  'gdietz': 105246,
#  'mdimitropoulouka': 106164,
#  'vdinesh': 107900,
#  'yid016': 128164,
#  'bdioneda': 168989,
#  'chd004': 170575,
#  'k4do': 105241,
#  'wdoan': 91600,
#  'fdong': 129696,
#  'j3dong': 98294,
#  'ddonskoy': 135973,
#  'ddoppala': 104477,
#  'andsouza': 142480,
#  'zedu': 97103,
#  'bdubois': 166952,
#  'mdulansk': 98313,
#  'hduong': 100344,
#  'ldwight': 107541,
#  'jweconomy': 137367,
#  'kekhlassi': 171654,
#  'senkhjargal': 168007,
#  'fenriquez': 166981,
#  'cerpeldi': 66006,
#  'jevalle': 99726,
#  'ctevans': 128331,
#  'sevtimova': 134831,
#  'lfasting': 170686,
#  'gfeghali': 168613,
#  'dfeliton': 129335,
#  'bfernandez': 108648,
#  'sfinch': 102927,
#  'lsfleig': 134432,
#  'jfleischer': 11286,
#  'kfleisch': 101491,
#  'hsflores': 130921,
#  'kefong': 99005,
#  'tfoster': 80996,
#  'sfrianeza': 170014,
#  'h6fu': 103949,
#  'xif001': 131623,
#  'bfune': 128425,
#  'jefung': 136551,
#  'pgaikwad': 135771,
#  'jgamm': 136823,
#  'lgan': 135320,
#  'a1ganesa': 94971,
#  'bigao': 131549,
#  'kdgao': 34976,
#  'e8garcia': 15279,
#  'kggarcia': 129735,
#  'mag026': 96896,
#  'sgaribayzaguilan': 107716,
#  'lgasser': 108020,
#  'pgaudet': 169328,
#  'aghai': 100638,
#  'nghosh': 129783,
#  'tgibbs': 17362,
#  'dgines': 136579,
#  'sgoh': 100151,
#  'sgong': 129503,
#  'v8gonzal': 102641,
#  'eag002': 133648,
#  'efg004': 167197,
#  'akgoswam': 99998,
#  'jgow': 103156,
#  'grader-cogs108-02': 145946,
#  'lgranger': 125371,
#  'jig036': 169969,
#  'kgugnani': 99002,
#  'mgujavarthi': 168304,
#  'jig015': 136257,
#  'xig003': 132230,
#  'xig001': 130702,
#  'yag007': 136633,
#  'hgurusan': 96754,
#  'bbhaber': 100805,
#  'bhacia': 107271,
#  'hhai': 168375,
#  'kham': 133445,
#  'ihamid': 138189,
#  'z4han': 107501,
#  'chao': 132420,
#  'vhasthi': 128912,
#  'jih063': 128344,
#  'xuh011': 130264,
#  'eheffernan': 107713,
#  'nihegde': 96969,
#  'phelcl': 96271,
#  'ahensel': 102216,
#  'arh003': 131336,
#  'ahewig': 141110,
#  'khidayat': 169710,
#  'vhinds': 128882,
#  'shirota': 135005,
#  'khho': 168681,
#  'lmho': 137646,
#  'qnhoang': 103386,
#  'gihoang': 166905,
#  'joh032': 170314,
#  'kkhoang': 108035,
#  'mlholland': 108302,
#  'choman': 130744,
#  'qihou': 102402,
#  'jchowe': 167662,
#  'zhh022': 131129,
#  'hohu': 105349,
#  'jih101': 168099,
#  'q7hu': 134529,
#  'vhu': 139090,
#  'xih035': 132190,
#  'jah003': 100114,
#  'keh004': 132079,
#  'roh002': 130323,
#  'r8huang': 100644,
#  'vihuang': 141729,
#  'yih045': 131674,
#  'pyhui': 100879,
#  'qhui': 95738,
#  'tchui': 95493,
#  'yuhung': 129391,
#  'diqbal': 110529,
#  'bjackola': 97234,
#  'ejao': 100403,
#  'ajayamohan': 165981,
#  'vjegadhe': 100837,
#  'yuj036': 128109,
#  'bojia': 130053,
#  'hojia': 168159,
#  'ajiang': 100080,
#  'c5jiang': 132637,
#  'dzjiang': 96236,
#  'fjiang': 129312,
#  'rojiang': 138145,
#  'wej002': 169754,
#  'jrjimenez': 136152,
#  'rojin': 169794,
#  'tjoel': 104952,
#  'ajohari': 83646,
#  'ajuljulian': 107548,
#  'aujung': 134700,
#  'ekakarla': 129808,
#  'wkam': 129324,
#  'jkaminsky': 135379,
#  'akamra': 169510,
#  'kekang': 139467,
#  'k9kang': 168471,
#  'rkant': 167849,
#  'amkao': 129728,
#  'jkarim': 171056,
#  'skaroval': 101920,
#  'pkatukojwala': 134395,
#  'ckavanagh': 133985,
#  'mdkawakami': 160810,
#  'tkawser': 139259,
#  'nekeodar': 45393,
#  'nokerendian': 163873,
#  'okhalil': 170460,
#  'dekhan': 96240,
#  'prkhanna': 132061,
#  'zakhater': 170679,
#  'mkhawaja': 171134,
#  'dki': 68706,
#  'dnkim': 68026,
#  'erk004': 131083,
#  'tkk002': 171314,
#  'hwk001': 99704,
#  'eyk005': 133737,
#  'juk019': 137726,
#  'kjk004': 132225,
#  'msk001': 77671,
#  'mik023': 103639,
#  'smkim': 108597,
#  'yek003': 103297,
#  'pking': 129223,
#  'aklinefelter': 127254,
#  'j3ko': 139887,
#  'nako': 170938,
#  'rkohli': 100361,
#  'd3kong': 127389,
#  'arkonnova': 130232,
#  'kku': 134050,
#  's4kumar': 130922,
#  'hykung': 168962,
#  'akunitad': 103910,
#  'jakwak': 16293,
#  'vkwan': 135894,
#  'gkweon': 103375,
#  'kkla': 132533,
#  'mslai': 131512,
#  'y2lai': 84206,
#  'aklam': 131574,
#  'pklam': 101886,
#  'jkl015': 170594,
#  'n2lam': 95531,
#  'ejlau': 107542,
#  'claw': 101841,
#  'jlazcano': 173383,
#  'bnle': 98862,
#  'gile': 132547,
#  'mhle': 133030,
#  'bnl002': 107481,
#  'chl147': 133651,
#  'dhl001': 132117,
#  'yul196': 131330,
#  'jjl027': 104544,
#  'jul050': 106002,
#  'kal030': 139361,
#  'kyl011': 141488,
#  'mml002': 132734,
#  'm5lee': 107151,
#  'nal008': 130704,
#  'nol001': 132979,
#  'tll001': 108708,
#  'mnleong': 129309,
#  'jyli': 94437,
#  'chl125': 128347,
#  'zil089': 170870,
#  'f3li': 100900,
#  'gjl001': 131066,
#  'jal039': 100048,
#  'jil237': 130300,
#  'lil010': 105419,
#  'mil049': 127861,
#  'ouli': 130912,
#  'qil008': 43232,
#  'rhli': 103513,
#  'shl127': 170346,
#  't8li': 95984,
#  'wuli': 104277,
#  'zil090': 170573,
#  'jil249': 136582,
#  'saliang': 131821,
#  's7liang': 127779,
#  'jyl013': 96265,
#  'zlim': 171627,
#  'del021': 157393,
#  'etl003': 134761,
#  'rhlin': 97257,
#  'chl135': 131073,
#  'cll006': 134367,
#  'rul020': 128339,
#  'mgliu': 138671,
#  'sal038': 131644,
#  'rlizaranmolina': 168713,
#  'jlizarra': 93205,
#  'mloeraar': 25140,
#  'vlohia': 95913,
#  'eplong': 130763,
#  'ealopez': 131585,
#  'ccl011': 132220,
#  'dhl003': 137351,
#  'yilou': 131104,
#  'gluengowoods': 168256,
#  'sxluong': 166995,
#  'j2lyu': 95525,
#  'a2ma': 133124,
#  'jum004': 134507,
#  'k6ma': 98047,
#  'lim007': 171286,
#  'zamahmood': 107746,
#  'smai': 97892,
#  'tbmai': 101569,
#  's2malik': 134312,
#  'samann': 168979,
#  'nmarthen': 136716,
#  'dam001': 96131,
#  'amasek': 129287,
#  'amathi': 99618,
#  'yamazaheri': 167191,
#  'mmckenziegarand': 168298,
#  'smejia': 107367,
#  'mmelkony': 102965,
#  'swmenon': 99379,
#  'rmeserve': 107002,
#  'anmiao': 105019,
#  's4min': 136797,
#  'emiranda': 99596,
#  'a1mishra': 107645,
#  'pmondrag': 102711,
#  'mamontano': 133108,
#  'gmoreau': 92397,
#  'mamorera': 133409,
#  'amorris': 103212,
#  'nmummala': 94372,
#  'mmuruganandam': 134467,
#  'shmusini': 131434,
#  'anag': 96039,
#  'unaik': 128282,
#  'p1nair': 137768,
#  'anarasimhan': 168611,
#  'sanarayanan': 131668,
#  'knelakon': 52040,
#  'akn022': 4273,
#  'ctn005': 98982,
#  'dkn003': 135702,
#  'emn005': 133112,
#  'kan005': 128163,
#  'kan024': 170853,
#  'ktn013': 95337,
#  'khn009': 104765,
#  'khn034': 54366,
#  'ltn011': 135736,
#  'nhn007': 109883,
#  'rmn001': 135690,
#  'rin002': 167989,
#  'tkn003': 133366,
#  'tan003': 103163,
#  'tin003': 126389,
#  'ton002': 128855,
#  'wvnguyen': 78811,
#  'snguyenphuoc': 106259,
#  'c5ni': 47697,
#  'jnishi': 104244,
#  'sbnorthrop': 124614,
#  'molmedo': 100730,
#  'klomar': 44931,
#  'j1ouyang': 129207,
#  'iozekici': 173393,
#  'tpagela': 106148,
#  'spamudji': 104871,
#  'kpansuri': 96332,
#  'npantfoerder': 140407,
#  'rpaquia': 107039,
#  'npareddy': 95061,
#  'anp072': 68746,
#  'bop002': 172884,
#  'jup006': 58473,
#  'khpark': 107315,
#  'saparvathaneni': 129333,
#  'v7patel': 133677,
#  'rpenchala': 131495,
#  'ipendlet': 99674,
#  'fepeng': 130719,
#  'fpeng': 108261,
#  'rpeng': 24678,
#  'z7peng': 99613,
#  'tpeterso': 104848,
#  'qphamnguyen': 136685,
#  'ttp007': 168241,
#  'baphan': 133705,
#  'c8phan': 124815,
#  'hvphan': 129850,
#  'htphan': 133727,
#  'apimple': 129125,
#  'spital': 127729,
#  'jpon': 100011,
#  'kponce': 132502,
#  'gpong': 166554,
#  'gprabhak': 93612,
#  'pprabhu': 135203,
#  'v1prado': 167018,
#  'anprasad': 98083,
#  'apremkumar': 135797,
#  'zpun': 169317,
#  'spuri': 107429,
#  'apurohit': 131018,
#  'pputtapa': 96312,
#  'k6qin': 63257,
#  'y7qin': 95289,
#  'ziqiu': 134557,
#  'kqu': 96744,
#  'grquach': 133551,
#  't1quach': 128375,
#  'niquach': 128522,
#  'bquijada': 127412,
#  's1rai': 97451,
#  'asraj': 132839,
#  'karaj': 168441,
#  'arraja': 156355,
#  'arajiv': 99424,
#  'arakha': 169157,
#  'sbramire': 102671,
#  'xjramirez': 134153,
#  'j8ramos': 167673,
#  'n1rashid': 127796,
#  'arasin': 94470,
#  'aravishankar': 132074,
#  'kkray': 137403,
#  'prebala': 133337,
#  'nregli': 66260,
#  'mrenteri': 99879,
#  'nrepetti': 96941,
#  'rriosram': 16685,
#  'crishi': 99612,
#  'groberg': 131608,
#  'arobertson': 129316,
#  'e7rodrig': 92025,
#  'hrodriguezterry': 128524,
#  'iroque': 102672,
#  'srote': 166914,
#  'drovira': 107161,
#  'trucker': 104423,
#  'awrussell': 134387,
#  'jasabio': 173277,
#  'asagundo': 26607,
#  'ssahar': 169974,
#  'shsam': 138732,
#  'mas026': 169558,
#  'pssanchez': 135971,
#  'r6sanche': 105081,
#  'gsandhu': 135425,
#  'ssankavaram': 108289,
#  'ssantacruzibarra': 158886,
#  'mesantos': 99397,
#  'vsastry': 101352,
#  'bsathappan': 133359,
#  'arsaxena': 127001,
#  'sschlagheck': 135381,
#  'hlschwartz': 129504,
#  'pseck': 103446,
#  'kseely': 99861,
#  'bsepulve': 103575,
#  'tshaikh': 141011,
#  'hushan': 134401,
#  'tsharifi': 170551,
#  'esharkov': 100640,
#  's5sharma': 135820,
#  'cas007': 129809,
#  'm3shen': 134098,
#  'xushi': 131007,
#  'dshi': 101203,
#  'dshin': 96233,
#  'hhshin': 134352,
#  'tjshin': 136512,
#  'n1shinde': 169380,
#  'c1shu': 133417,
#  'vshu': 103272,
#  'x1shu': 133356,
#  'arshukla': 132235,
#  'jshyu': 136075,
#  'asierra': 105137,
#  'osimonds': 171065,
#  'jsimpauco': 130660,
#  'gus001': 125424,
#  'r1singh': 97105,
#  'ysingh': 104873,
#  'bsison': 169757,
#  'ssitu': 102719,
#  'anslyker': 128257,
#  'asmithwick': 160049,
#  'miso': 168889,
#  'json': 95295,
#  'e7song': 136784,
#  'kjsong': 140061,
#  'asonti': 136616,
#  'kpstern': 104281,
#  'sdsteven': 94407,
#  'estratford': 134302,
#  'jstreett': 134408,
#  'asubbarao': 173394,
#  'tsugita': 107961,
#  'e2sun': 108148,
#  'mis005': 104212,
#  'mis008': 168675,
#  'rzsun': 137866,
#  'rsunku': 133033,
#  'wsupian': 133476,
#  'arsureshkumar': 158104,
#  'ansuresh': 134012,
#  'vswamy': 132071,
#  'mszeto': 133026,
#  'stalanki': 103007,
#  'm1tam': 104875,
#  'cktan': 30341,
#  'jit011': 170322,
#  'mntan': 102013,
#  'cht019': 170169,
#  'mjtang': 136062,
#  'otang': 126395,
#  'fetang': 129664,
#  'y6tang': 97203,
#  'jtanurdjaja': 132129,
#  'rtay': 103234,
#  'sytaylor': 107982,
#  'jtello': 136555,
#  'brobertthaddeus': 136672,
#  'jqthai': 135711,
#  'tithai': 166891,
#  'nthiyagarajan': 135799,
#  'dithomas': 171542,
#  'bthome': 107802,
#  'yut009': 132991,
#  'lto': 108758,
#  'ctomlin': 134875,
#  'htonnu': 135976,
#  'ant034': 171136,
#  'dktran': 108509,
#  'pjtran': 106672,
#  'sat001': 107572,
#  'ntrejo': 101155,
#  'trtruong': 101983,
#  'j1tsai': 97278,
#  'htse': 132773,
#  'antseng': 168053,
#  'jtutak': 129817,
#  'vtyagi': 133665,
#  'suppu': 33060,
#  'rusmanova': 138528,
#  'svaldimarsdottir': 166937,
#  'ajvalencia': 130681,
#  'svallumchetla': 133913,
#  'kvankirk': 106329,
#  'ivarela': 100575,
#  'avasanth': 129241,
#  'a2vazque': 99845,
#  'ivenzon': 170550,
#  'atvilays': 48388,
#  'svirk': 99247,
#  'pviwatkurkul': 132673,
#  'ahvu': 131757,
#  'ervu': 168424,
#  'kmvu': 127733,
#  'kdvu': 133504,
#  'trvu': 126417,
#  'ctwalsh': 136785,
#  'z4wan': 101595,
#  'shw050': 102630,
#  'anw010': 129567,
#  'shw081': 132336,
#  'jhw009': 139261,
#  'haw086': 169638,
#  'kuw010': 129236,
#  'yuw096': 97061,
#  'l3wang': 96202,
#  'piw001': 140172,
#  'ruw008': 98708,
#  'siw031': 133412,
#  'yiw072': 95029,
#  'thw001': 95906,
#  'etwaters': 168429,
#  'z5wei': 129200,
#  'bwelles': 136202,
#  'mwelsome': 95013,
#  'x7wen': 136884,
#  'anwen': 136454,
#  'mwidyadh': 102730,
#  'jaw018': 133607,
#  'juw024': 103541,
#  'khw001': 132525,
#  'kew027': 169598,
#  'rdwong': 129220,
#  'v9wong': 171110,
#  'wcw003': 170760,
#  'kewoo': 136387,
#  'anw002': 108445,
#  'daw010': 136924,
#  'd7wu': 99995,
#  'd5wu': 96248,
#  'haw189': 10097,
#  'jzwu': 95712,
#  'jiw118': 133594,
#  'jjwu': 108008,
#  'juw050': 167667,
#  't8wu': 100057,
#  'yuw135': 129639,
#  'bbxia': 130120,
#  'mxian': 97414,
#  'alxiao': 133096,
#  'r3xiao': 136035,
#  'yaxiao': 103423,
#  'ejxiong': 131814,
#  'max003': 99841,
#  'p3xu': 131732,
#  'yax016': 167961,
#  'zhx003': 100748,
#  'c4yan': 99288,
#  'yyanagawa': 105446,
#  'boyang': 38116,
#  'r6yang': 96899,
#  'hey001': 103623,
#  'huy005': 128795,
#  'jey013': 136073,
#  'yuy004': 69877,
#  'jyangari': 129582,
#  'lyazouri': 108552,
#  'a1ye': 107372,
#  'eyenikomshian': 134241,
#  'z5ying': 8567,
#  'jyyip': 101860,
#  'jyip': 95006,
#  'dyonemura': 106076,
#  'joy005': 106490,
#  'key010': 137002,
#  'key009': 132152,
#  'hsy002': 170865,
#  'tyyu': 97235,
#  'xiy005': 96286,
#  'yay019': 71626,
#  'z2yu': 91636,
#  'z8yuan': 131877,
#  'czakkour': 106880,
#  'boz002': 138620,
#  'yiz029': 95825,
#  'liz035': 137051,
#  'jiz145': 127808,
#  'jiz147': 129253,
#  'k3zhang': 34465,
#  'lez002': 95904,
#  'luz010': 127844,
#  'miz030': 166846,
#  'nwzhang': 132703,
#  'zhz084': 130112,
#  'zhz044': 94249,
#  'ziz057': 134859,
#  'yuz159': 127238,
#  'jazheng': 99571,
#  'shz054': 130720,
#  'ruzhong': 130569,
#  'y4zhong': 98017,
#  'alz007': 165074,
#  'e4zhou': 171822,
#  'k9zhou': 129852,
#  'lazhou': 102380,
#  'liz009': 96199,
#  'shz040': 109592,
#  'azhuchou': 97046,
#  'b2zhu': 129500,
#  'brzhu': 133015,
#  'haz042': 103047,
#  'r2zhu': 126239,
#  'yiz123': 104071,
#  'yiz036': 96826,
#  'l1zhuo': 132227,
#  'bzou': 105565,
#  'hazou': 127805}

# %%
len(student_ids)
# Out:
# 743

# %%
def extract_unique_login_ids(file_path, column_name):
    unique_login_ids = set()

    with open(file_path, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            email_address = row[column_name]
            login_id = email_address.split('@')[0]
            unique_login_ids.add(login_id)

    return unique_login_ids

# Usage
unique_login_ids = extract_unique_login_ids(file_path, column_name)

# %%
unique_login_ids
# Out:
# {'a1agrawal',
#  'a1foster',
#  'a1ganesa',
#  'a1mishra',
#  'a1ye',
#  'a2akbari',
#  'a2ma',
#  'a2vazque',
#  'a3chao',
#  'a5wu',
#  'a6aggarw',
#  'aaaparic',
#  'aaboushaaban',
#  'aacameron',
#  'aalghazouli',
#  'aapiado',
#  'aaverbuj',
#  'ababoescu',
#  'abanwait',
#  'aborjasquintanilla',
#  'acalza',
#  'accalibuso',
#  'achavarria',
#  'achowdhry',
#  'acn001',
#  'acrawley',
#  'adagrawal',
#  'adarun',
#  'adevineni',
#  'adm008',
#  'agao',
#  'aghai',
#  'ahensel',
#  'ahmostafa',
#  'ahvu',
#  'ajayamohan',
#  'ajiang',
#  'ajohari',
#  'ajuljulian',
#  'ajvalencia',
#  'akamra',
#  'akgoswam',
#  'aklam',
#  'aklinefelter',
#  'akn022',
#  'akunitad',
#  'alxiao',
#  'alz007',
#  'amasek',
#  'amathi',
#  'amkao',
#  'amkrtych',
#  'amorris',
#  'anag',
#  'anarasimhan',
#  'anavanal',
#  'and002',
#  'andang',
#  'andsouza',
#  'anmiao',
#  'anprasad',
#  'anslyker',
#  'ansuresh',
#  'ant010',
#  'ant034',
#  'antseng',
#  'anw002',
#  'anw010',
#  'anwen',
#  'apimple',
#  'apremkumar',
#  'apurohit',
#  'arajiv',
#  'arakha',
#  'arasin',
#  'aravishankar',
#  'arkonnova',
#  'arobertson',
#  'arraja',
#  'arsaxena',
#  'arshukla',
#  'arsureshkumar',
#  'asagundo',
#  'asierra',
#  'asmithwick',
#  'asonti',
#  'asubbarao',
#  'atvilays',
#  'aujung',
#  'avasanth',
#  'avkaur',
#  'awrussell',
#  'ayussuf',
#  'azc001',
#  'azhuchou',
#  'b2zhu',
#  'b9park',
#  'baphan',
#  'basami',
#  'bbeeson',
#  'bbhaber',
#  'bbuckhan',
#  'bbudiputra',
#  'bbxia',
#  'bdioneda',
#  'bdubois',
#  'bec002',
#  'bephraim',
#  'bfernandez',
#  'bfune',
#  'bhacia',
#  'bhc001',
#  'bhemmaty',
#  'bhinnant',
#  'bigao',
#  'bjackola',
#  'bjburke',
#  'bnl002',
#  'bnle',
#  'bojia',
#  'bolivarez',
#  'bop002',
#  'boz002',
#  'bquijada',
#  'brchu',
#  'brobertthaddeus',
#  'brzhu',
#  'bsathappan',
#  'bschan',
#  'bsepulve',
#  'bsison',
#  'bthome',
#  'bwelles',
#  'bzou',
#  'c1shu',
#  'c4yan',
#  'c5jiang',
#  'c5ni',
#  'c8phan',
#  'cas007',
#  'ccl011',
#  'cdermanuelian',
#  'cerpeldi',
#  'chao',
#  'chc057',
#  'chd004',
#  'chl125',
#  'chl135',
#  'chl147',
#  'chn032',
#  'choman',
#  'cht019',
#  'chw081',
#  'chzhao',
#  'ckavanagh',
#  'cktan',
#  'claw',
#  'cll006',
#  'crishi',
#  'ctevans',
#  'ctn005',
#  'ctomlin',
#  'ctsui',
#  'ctwalsh',
#  'd3kong',
#  'd5wu',
#  'd7wu',
#  'dam001',
#  'daw010',
#  'dcarrion',
#  'ddelabarreda',
#  'dderasar',
#  'ddonskoy',
#  'dekhan',
#  'del021',
#  'dfeliton',
#  'dgines',
#  'dhl001',
#  'dithomas',
#  'djang',
#  'djpark',
#  'dki',
#  'dkn003',
#  'dktran',
#  'dlchan',
#  'dnkim',
#  'drovira',
#  'dshi',
#  'dshin',
#  'dyonemura',
#  'dzjiang',
#  'e2sun',
#  'e4zhou',
#  'e7rodrig',
#  'e7song',
#  'e8garcia',
#  'eag002',
#  'ealopez',
#  'efg004',
#  'ehcho',
#  'eheffernan',
#  'ejao',
#  'ejlau',
#  'ejxiong',
#  'ekushwaha',
#  'eldelrosario',
#  'emiranda',
#  'emn005',
#  'enchin',
#  'eplong',
#  'erk004',
#  'ervu',
#  'esestrada',
#  'esharkov',
#  'estratford',
#  'etchen',
#  'etl003',
#  'etwaters',
#  'evchan',
#  'eyenikomshian',
#  'eyk005',
#  'ezdeng',
#  'f3li',
#  'fdiamond',
#  'fdong',
#  'fenriquez',
#  'fepeng',
#  'fetang',
#  'fjiang',
#  'fpeng',
#  'gamirian',
#  'gangelici',
#  'gbarrosk',
#  'gbutters',
#  'gdietz',
#  'gfeghali',
#  'gihoang',
#  'gjaroli',
#  'gjchen',
#  'gjl001',
#  'gkweon',
#  'gluengowoods',
#  'gmoreau',
#  'gpong',
#  'gprabhak',
#  'groberg',
#  'grquach',
#  'gsandhu',
#  'gus001',
#  'h2choi',
#  'h3cai',
#  'h6fu',
#  'h9cheng',
#  'hashcroft',
#  'haw086',
#  'haw189',
#  'haz042',
#  'hazou',
#  'hbrownell',
#  'hdehaini',
#  'hduong',
#  'hey001',
#  'hgurusan',
#  'hhai',
#  'hhn007',
#  'hhshin',
#  'hic001',
#  'hlschwartz',
#  'hohu',
#  'hojia',
#  'hqarana',
#  'hrodriguezterry',
#  'hsflores',
#  'hsy002',
#  'htonnu',
#  'htphan',
#  'htse',
#  'hushan',
#  'huy005',
#  'hvphan',
#  'hwk001',
#  'hykung',
#  'i1cheng',
#  'iaballa',
#  'iachai',
#  'ihamid',
#  'iozekici',
#  'ipendlet',
#  'iroque',
#  'ivarela',
#  'ivenzon',
#  'j1ouyang',
#  'j1tsai',
#  'j2lyu',
#  'j3ko',
#  'j5dai',
#  'j8bui',
#  'j8cao',
#  'j8ramos',
#  'jabondano',
#  'jac018',
#  'jah003',
#  'jakwak',
#  'jal039',
#  'jalinas',
#  'janayagarcia',
#  'jariss',
#  'jartley',
#  'jasabio',
#  'jaw018',
#  'jazheng',
#  'jbanawa',
#  'jcc002',
#  'jchowe',
#  'jdegraaf',
#  'jedang',
#  'jefung',
#  'jevalle',
#  'jey013',
#  'jgamm',
#  'jgow',
#  'jhw009',
#  'jic052',
#  'jig015',
#  'jig036',
#  'jih063',
#  'jih101',
#  'jil237',
#  'jil249',
#  'jit011',
#  'jiw118',
#  'jiz145',
#  'jiz147',
#  'jiz152',
#  'jjl027',
#  'jjwu',
#  'jkaminsky',
#  'jkarim',
#  'jkl015',
#  'jlizarra',
#  'jlnomura',
#  'jmcole',
#  'jmsin',
#  'jnishi',
#  'joh032',
#  'jolo',
#  'joteh',
#  'joy005',
#  'jpon',
#  'jqthai',
#  'jrarreguin',
#  'jraynovi',
#  'jrjimenez',
#  'jshyu',
#  'jsimpauco',
#  'json',
#  'jstreett',
#  'jtanurdjaja',
#  'jtcastillo',
#  'jtello',
#  'jtutak',
#  'juh016',
#  'juk019',
#  'jul050',
#  'jum004',
#  'jup006',
#  'jusin',
#  'juw024',
#  'juw050',
#  'jweconomy',
#  'jyangari',
#  'jyip',
#  'jyl013',
#  'jyli',
#  'jyyip',
#  'jzwu',
#  'k1chang',
#  'k3zhang',
#  'k4do',
#  'k6ma',
#  'k6qin',
#  'k9kang',
#  'k9zhou',
#  'kal030',
#  'kan005',
#  'kan024',
#  'karaj',
#  'karcos',
#  'kdvu',
#  'kec021',
#  'kefong',
#  'keh004',
#  'kekang',
#  'kekhlassi',
#  'ken004',
#  'kew027',
#  'kewoo',
#  'key009',
#  'key010',
#  'kfleisch',
#  'kggarcia',
#  'kgugnani',
#  'kham',
#  'khho',
#  'khidayat',
#  'khn009',
#  'khn034',
#  'khpark',
#  'khw001',
#  'kjchou',
#  'kjk004',
#  'kjsong',
#  'kkhoang',
#  'kkla',
#  'kkray',
#  'kku',
#  'kmvu',
#  'knelakon',
#  'kpansuri',
#  'kponce',
#  'kpstern',
#  'kqtran',
#  'kqu',
#  'kseely',
#  'ksisouk',
#  'ktn013',
#  'kuw010',
#  'kvankirk',
#  'kwchin',
#  'kyl011',
#  'kymartinez',
#  'l1zhuo',
#  'l3wang',
#  'ladarlin',
#  'lazhou',
#  'lballest',
#  'ldai',
#  'ldwight',
#  'lecai',
#  'lez002',
#  'lfasting',
#  'lgan',
#  'lgasser',
#  'lgranger',
#  'licarrillo',
#  'lil010',
#  'lim007',
#  'liz009',
#  'liz035',
#  'llong',
#  'lmartinezchun',
#  'lmho',
#  'lnhernan',
#  'lsfleig',
#  'ltn011',
#  'lto',
#  'luz010',
#  'lyazouri',
#  'm1tam',
#  'm3shen',
#  'm5lee',
#  'madebiyi',
#  'mag026',
#  'mamontano',
#  'mamorera',
#  'mas026',
#  'mashen',
#  'max003',
#  'mbach',
#  'mbblack',
#  'mbuan',
#  'mdayanan',
#  'mdimitropoulouka',
#  'mdkawakami',
#  'mdulansk',
#  'meburrows',
#  'mec005',
#  'mec009',
#  'mesantos',
#  'mew015',
#  'mgliu',
#  'mgujavarthi',
#  'mhle',
#  'mic035',
#  'mik023',
#  'mil049',
#  'mis005',
#  'mis008',
#  'miso',
#  'miz030',
#  'mjgaray',
#  'mjtang',
#  'mkhawaja',
#  'mlholland',
#  'mmckenziegarand',
#  'mmdavid',
#  'mmelkony',
#  'mml002',
#  'mmuruganandam',
#  'mnarain',
#  'mndiaz',
#  'mnleong',
#  'mnolson',
#  'mntan',
#  'molmedo',
#  'mpacomendivil',
#  'mrenteri',
#  'msaez',
#  'msk001',
#  'mslai',
#  'mszeto',
#  'mwelsome',
#  'mwidyadh',
#  'mxian',
#  'n1rashid',
#  'n1shinde',
#  'n2lam',
#  'naalami',
#  'nachiang',
#  'nako',
#  'nal008',
#  'narumugam',
#  'nbajaj',
#  'nboloori',
#  'nccronin',
#  'nchepuri',
#  'ncote',
#  'ncrawley',
#  'nekeodar',
#  'nghosh',
#  'nhn007',
#  'nihegde',
#  'niquach',
#  'njchu',
#  'njmorales',
#  'nmarthen',
#  'nmoranbautista',
#  'nmummala',
#  'nokerendian',
#  'nol001',
#  'npantfoerder',
#  'npareddy',
#  'nregli',
#  'nrepetti',
#  'ntchung',
#  'nthiyagarajan',
#  'ntrejo',
#  'nwzhang',
#  'obychenkov',
#  'okhalil',
#  'osimonds',
#  'otang',
#  'ouli',
#  'p1chiang',
#  'p1nair',
#  'p3xu',
#  'pel028',
#  'pew008',
#  'pgaikwad',
#  'pgaudet',
#  'phelcl',
#  'piw001',
#  'pjduggal',
#  'pjtran',
#  'pkatukojwala',
#  'pking',
#  'pklam',
#  'plsanche',
#  'pmondrag',
#  'pprabhu',
#  'pputtapa',
#  'prebala',
#  'prkhanna',
#  'pseck',
#  'pssanchez',
#  'pviwatkurkul',
#  'pyhui',
#  'q7hu',
#  'q8chen',
#  'qhui',
#  'qihou',
#  'qil008',
#  'qphamnguyen',
#  'quzeng',
#  'r1singh',
#  'r2zhu',
#  'r3xiao',
#  'r6sanche',
#  'r6yang',
#  'r8huang',
#  'rbaldoz',
#  'rdoh',
#  'rduvur',
#  'rdwong',
#  'rhli',
#  'rhlin',
#  'rin002',
#  'rkant',
#  'rlizaranmolina',
#  'rmali',
#  'rmeserve',
#  'rmiura',
#  'rmn001',
#  'roh002',
#  'rojiang',
#  'rojin',
#  'rpaquia',
#  'rpenchala',
#  'rpeng',
#  'rriosram',
#  'rsunku',
#  'rtay',
#  'rul020',
#  'rusmanova',
#  'ruw008',
#  'ruzhong',
#  'ryla',
#  'rzsun',
#  's1rai',
#  's2malik',
#  's4kumar',
#  's4min',
#  's5sharma',
#  's6wei',
#  's7liang',
#  'sal038',
#  'sal059',
#  'saliang',
#  'salsawaf',
#  'samann',
#  'sanarayanan',
#  'saparvathaneni',
#  'sat001',
#  'sbnorthrop',
#  'sboddy',
#  'sbramire',
#  'sdimmock',
#  'sdsteven',
#  'senkhjargal',
#  'sevtimova',
#  'sfinch',
#  'sfrianeza',
#  'sgaribayzaguilan',
#  'sgoh',
#  'sgong',
#  'shirota',
#  'shl127',
#  'shmayo',
#  'shmusini',
#  'shsam',
#  'shw050',
#  'shw081',
#  'shz040',
#  'shz054',
#  'sic018',
#  'siw031',
#  'sjc003',
#  'skaroval',
#  'smahamed',
#  'smai',
#  'smejia',
#  'smkim',
#  'snguyenphuoc',
#  'spamudji',
#  'spital',
#  'spuri',
#  'sragarwa',
#  'srote',
#  'ssahar',
#  'ssankavaram',
#  'ssantacruzibarra',
#  'sschlagheck',
#  'stalanki',
#  'stchavez',
#  'stn017',
#  'suaye',
#  'suppu',
#  'svaldimarsdottir',
#  'svallumchetla',
#  'svirk',
#  'swchan',
#  'swmenon',
#  'sxluong',
#  'sytaylor',
#  't1quach',
#  't8li',
#  't8wu',
#  'tan003',
#  'tbmai',
#  'tchui',
#  'tfoster',
#  'tgibbs',
#  'thw001',
#  'tibao',
#  'tin003',
#  'tithai',
#  'tjoel',
#  'tjshin',
#  'tkk002',
#  'tkn003',
#  'tll001',
#  'tmcooper',
#  'ton002',
#  'tpagela',
#  'tpeterso',
#  'trhussain',
#  'trtruong',
#  'trucker',
#  'trvu',
#  'tsharifi',
#  'tsugita',
#  'ttp007',
#  'tyyu',
#  'unaik',
#  'v1prado',
#  'v4lee',
#  'v7patel',
#  'v8gonzal',
#  'v9wong',
#  'vdinesh',
#  'vhasthi',
#  'vhinds',
#  'vhu',
#  'vihuang',
#  'vkwan',
#  'vlohia',
#  'vrajpurohit',
#  'vsastry',
#  'vshu',
#  'vswamy',
#  'w9chan',
#  'w9lin',
#  'wcw003',
#  'wdoan',
#  'wej002',
#  'wiz001',
#  'wkam',
#  'wsupian',
#  'wuli',
#  'x1shu',
#  'x6guo',
#  'x7wen',
#  'xif001',
#  'xig001',
#  'xig003',
#  'xih035',
#  'xiy005',
#  'xjramirez',
#  'xuh011',
#  'xushi',
#  'y2bu',
#  'y2lai',
#  'y4zhong',
#  'y5gong',
#  'y6tang',
#  'y7qin',
#  'yaf003',
#  'yag007',
#  'yamazaheri',
#  'yax016',
#  'yaxiao',
#  'yay019',
#  'yechoi',
#  'yek003',
#  'yic057',
#  'yic075',
#  'yic079',
#  'yid016',
#  'yih045',
#  'yilou',
#  'yiw072',
#  'yiw167',
#  'yiz029',
#  'yiz036',
#  'yiz121',
#  'yiz123',
#  'yiz159',
#  'ysingh',
#  'yug040',
#  'yuhung',
#  'yuj036',
#  'yul196',
#  'yul235',
#  'yut009',
#  'yuw096',
#  'yuw135',
#  'yuz159',
#  'yyanagawa',
#  'z2yu',
#  'z4cai',
#  'z4han',
#  'z4wan',
#  'z5wei',
#  'z7peng',
#  'z8yuan',
#  'zakhater',
#  'zedu',
#  'zhh022',
#  'zhx003',
#  'zhz044',
#  'zhz084',
#  'zic035',
#  'zih029',
#  'zil089',
#  'zil090',
#  'ziqiu',
#  'ziz054',
#  'ziz057',
#  'zlim',
#  'znabulsi',
#  'zpun'}

# %%
len(unique_login_ids)
# Out:
# 811

# %%
def publish_scores(course_id, assignment_id, student_ids, unique_login_ids, api_url, api_key, score):
    headers = {"Authorization": f"Bearer {api_key}"}

    for login_id in unique_login_ids:
        student_id = student_ids.get(login_id)
        if student_id:
            endpoint = f"{api_url}/api/v1/courses/{course_id}/assignments/{assignment_id}/submissions/{student_id}"
            payload = {"submission": {"posted_grade": score}}
            response = requests.put(endpoint, headers=headers, json=payload)

            if response.status_code == 200:
                print(f"Score {score} published for student ID {student_id} (login ID: {login_id}).")
            else:
                print(f"Failed to publish score for student ID {student_id} (login ID: {login_id}): {response.text}")

# %%
publish_scores(COURSE_ID, ASSIGNMENT_ID, student_ids, unique_login_ids, API_URL, API_KEY, SCORE)
# Out:
# Score 0.25 published for student ID 132673 (login ID: pviwatkurkul).
# Score 0.25 published for student ID 133366 (login ID: tkn003).
# Score 0.25 published for student ID 129200 (login ID: z5wei).
# Score 0.25 published for student ID 99998 (login ID: akgoswam).
# Score 0.25 published for student ID 131608 (login ID: groberg).
# Score 0.25 published for student ID 130120 (login ID: bbxia).
# Score 0.25 published for student ID 170628 (login ID: suaye).
# Score 0.25 published for student ID 170575 (login ID: chd004).
# Score 0.25 published for student ID 43232 (login ID: qil008).
# Score 0.25 published for student ID 99725 (login ID: k1chang).
# Score 0.25 published for student ID 138145 (login ID: rojiang).
# Score 0.25 published for student ID 169710 (login ID: khidayat).
# Score 0.25 published for student ID 47697 (login ID: c5ni).
# Score 0.25 published for student ID 128339 (login ID: rul020).
# Score 0.25 published for student ID 108708 (login ID: tll001).
# Score 0.25 published for student ID 129582 (login ID: jyangari).
# Score 0.25 published for student ID 83646 (login ID: ajohari).
# Score 0.25 published for student ID 170322 (login ID: jit011).
# Score 0.25 published for student ID 107372 (login ID: a1ye).
# Score 0.25 published for student ID 95906 (login ID: thw001).
# Score 0.25 published for student ID 133494 (login ID: achowdhry).
# Score 0.25 published for student ID 127001 (login ID: arsaxena).
# Score 0.25 published for student ID 103163 (login ID: tan003).
# Score 0.25 published for student ID 129223 (login ID: pking).
# Score 0.25 published for student ID 107541 (login ID: ldwight).
# Score 0.25 published for student ID 135702 (login ID: dkn003).
# Score 0.25 published for student ID 137646 (login ID: lmho).
# Score 0.25 published for student ID 135203 (login ID: pprabhu).
# Score 0.25 published for student ID 168053 (login ID: antseng).
# Score 0.25 published for student ID 71626 (login ID: yay019).
# Score 0.25 published for student ID 102216 (login ID: ahensel).
# Score 0.25 published for student ID 136736 (login ID: adevineni).
# Score 0.25 published for student ID 141509 (login ID: ncrawley).
# Score 0.25 published for student ID 95952 (login ID: mec005).
# Score 0.25 published for student ID 132117 (login ID: dhl001).
# Score 0.25 published for student ID 129241 (login ID: avasanth).
# Score 0.25 published for student ID 129287 (login ID: amasek).
# Score 0.25 published for student ID 169141 (login ID: madebiyi).
# Score 0.25 published for student ID 168304 (login ID: mgujavarthi).
# Score 0.25 published for student ID 132427 (login ID: sic018).
# Score 0.25 published for student ID 95525 (login ID: j2lyu).
# Score 0.25 published for student ID 104544 (login ID: jjl027).
# Score 0.25 published for student ID 133096 (login ID: alxiao).
# Score 0.25 published for student ID 94437 (login ID: jyli).
# Score 0.25 published for student ID 98862 (login ID: bnle).
# Score 0.25 published for student ID 138528 (login ID: rusmanova).
# Score 0.25 published for student ID 130313 (login ID: jac018).
# Score 0.25 published for student ID 167691 (login ID: hdehaini).
# Score 0.25 published for student ID 92379 (login ID: mdayanan).
# Score 0.25 published for student ID 136062 (login ID: mjtang).
# Score 0.25 published for student ID 133594 (login ID: jiw118).
# Score 0.25 published for student ID 104423 (login ID: trucker).
# Score 0.25 published for student ID 172661 (login ID: aalghazouli).
# Score 0.25 published for student ID 130053 (login ID: bojia).
# Score 0.25 published for student ID 100644 (login ID: r8huang).
# Score 0.25 published for student ID 107481 (login ID: bnl002).
# Score 0.25 published for student ID 107900 (login ID: vdinesh).
# Score 0.25 published for student ID 136884 (login ID: x7wen).
# Score 0.25 published for student ID 169754 (login ID: wej002).
# Score 0.25 published for student ID 170488 (login ID: a3chao).
# Score 0.25 published for student ID 104071 (login ID: yiz123).
# Score 0.25 published for student ID 138620 (login ID: boz002).
# Score 0.25 published for student ID 133648 (login ID: eag002).
# Score 0.25 published for student ID 135711 (login ID: jqthai).
# Score 0.25 published for student ID 104281 (login ID: kpstern).
# Score 0.25 published for student ID 95493 (login ID: tchui).
# Score 0.25 published for student ID 102730 (login ID: mwidyadh).
# Score 0.25 published for student ID 100114 (login ID: jah003).
# Score 0.25 published for student ID 136512 (login ID: tjshin).
# Score 0.25 published for student ID 134529 (login ID: q7hu).
# Score 0.25 published for student ID 167122 (login ID: licarrillo).
# Score 0.25 published for student ID 108509 (login ID: dktran).
# Score 0.25 published for student ID 132330 (login ID: ehcho).
# Score 0.25 published for student ID 103045 (login ID: yic057).
# Score 0.25 published for student ID 103639 (login ID: mik023).
# Score 0.25 published for student ID 107961 (login ID: tsugita).
# Score 0.25 published for student ID 128524 (login ID: hrodriguezterry).
# Score 0.25 published for student ID 103343 (login ID: bbuckhan).
# Score 0.25 published for student ID 107444 (login ID: nccronin).
# Score 0.25 published for student ID 126389 (login ID: tin003).
# Score 0.25 published for student ID 170728 (login ID: jabondano).
# Score 0.25 published for student ID 136685 (login ID: qphamnguyen).
# Score 0.25 published for student ID 134012 (login ID: ansuresh).
# Score 0.25 published for student ID 133504 (login ID: kdvu).
# Score 0.25 published for student ID 99618 (login ID: amathi).
# Score 0.25 published for student ID 92397 (login ID: gmoreau).
# Score 0.25 published for student ID 77671 (login ID: msk001).
# Score 0.25 published for student ID 91636 (login ID: z2yu).
# Score 0.25 published for student ID 100344 (login ID: hduong).
# Score 0.25 published for student ID 102013 (login ID: mntan).
# Score 0.25 published for student ID 170594 (login ID: jkl015).
# Score 0.25 published for student ID 171136 (login ID: ant034).
# Score 0.25 published for student ID 130323 (login ID: roh002).
# Score 0.25 published for student ID 97951 (login ID: gbarrosk).
# Score 0.25 published for student ID 91600 (login ID: wdoan).
# Score 0.25 published for student ID 80996 (login ID: tfoster).
# Score 0.25 published for student ID 131073 (login ID: chl135).
# Score 0.25 published for student ID 136551 (login ID: jefung).
# Score 0.25 published for student ID 141729 (login ID: vihuang).
# Score 0.25 published for student ID 66006 (login ID: cerpeldi).
# Score 0.25 published for student ID 100575 (login ID: ivarela).
# Score 0.25 published for student ID 100640 (login ID: esharkov).
# Score 0.25 published for student ID 124994 (login ID: meburrows).
# Score 0.25 published for student ID 108261 (login ID: fpeng).
# Score 0.25 published for student ID 135820 (login ID: s5sharma).
# Score 0.25 published for student ID 129735 (login ID: kggarcia).
# Score 0.25 published for student ID 105241 (login ID: k4do).
# Score 0.25 published for student ID 128331 (login ID: ctevans).
# Score 0.25 published for student ID 131644 (login ID: sal038).
# Score 0.25 published for student ID 163873 (login ID: nokerendian).
# Score 0.25 published for student ID 126417 (login ID: trvu).
# Score 0.25 published for student ID 101155 (login ID: ntrejo).
# Score 0.25 published for student ID 168675 (login ID: mis008).
# Score 0.25 published for student ID 169974 (login ID: ssahar).
# Score 0.25 published for student ID 133401 (login ID: kec021).
# Score 0.25 published for student ID 129333 (login ID: saparvathaneni).
# Score 0.25 published for student ID 158886 (login ID: ssantacruzibarra).
# Score 0.25 published for student ID 133476 (login ID: wsupian).
# Score 0.25 published for student ID 136672 (login ID: brobertthaddeus).
# Score 0.25 published for student ID 133417 (login ID: c1shu).
# Score 0.25 published for student ID 107245 (login ID: bhc001).
# Score 0.25 published for student ID 130720 (login ID: shz054).
# Score 0.25 published for student ID 134241 (login ID: eyenikomshian).
# Score 0.25 published for student ID 132991 (login ID: yut009).
# Score 0.25 published for student ID 139467 (login ID: kekang).
# Score 0.25 published for student ID 131434 (login ID: shmusini).
# Score 0.25 published for student ID 170550 (login ID: ivenzon).
# Score 0.25 published for student ID 103400 (login ID: bschan).
# Score 0.25 published for student ID 168681 (login ID: khho).
# Score 0.25 published for student ID 132071 (login ID: vswamy).
# Score 0.25 published for student ID 99879 (login ID: mrenteri).
# Score 0.25 published for student ID 97414 (login ID: mxian).
# Score 0.25 published for student ID 102927 (login ID: sfinch).
# Score 0.25 published for student ID 135690 (login ID: rmn001).
# Score 0.25 published for student ID 166995 (login ID: sxluong).
# Score 0.25 published for student ID 130569 (login ID: ruzhong).
# Score 0.25 published for student ID 106259 (login ID: snguyenphuoc).
# Score 0.25 published for student ID 134808 (login ID: mmdavid).
# Score 0.25 published for student ID 142480 (login ID: andsouza).
# Score 0.25 published for student ID 135425 (login ID: gsandhu).
# Score 0.25 published for student ID 169558 (login ID: mas026).
# Score 0.25 published for student ID 167717 (login ID: jalinas).
# Score 0.25 published for student ID 54366 (login ID: khn034).
# Score 0.25 published for student ID 95013 (login ID: mwelsome).
# Score 0.25 published for student ID 81727 (login ID: jbanawa).
# Score 0.25 published for student ID 99861 (login ID: kseely).
# Score 0.25 published for student ID 133538 (login ID: j8cao).
# Score 0.25 published for student ID 170460 (login ID: okhalil).
# Score 0.25 published for student ID 103234 (login ID: rtay).
# Score 0.25 published for student ID 128375 (login ID: t1quach).
# Score 0.25 published for student ID 97278 (login ID: j1tsai).
# Score 0.25 published for student ID 106076 (login ID: dyonemura).
# Score 0.25 published for student ID 137051 (login ID: liz035).
# Score 0.25 published for student ID 168889 (login ID: miso).
# Score 0.25 published for student ID 173393 (login ID: iozekici).
# Score 0.25 published for student ID 103375 (login ID: gkweon).
# Score 0.25 published for student ID 99002 (login ID: kgugnani).
# Score 0.25 published for student ID 136454 (login ID: anwen).
# Score 0.25 published for student ID 34465 (login ID: k3zhang).
# Score 0.25 published for student ID 135320 (login ID: lgan).
# Score 0.25 published for student ID 137726 (login ID: juk019).
# Score 0.25 published for student ID 166914 (login ID: srote).
# Score 0.25 published for student ID 133727 (login ID: htphan).
# Score 0.25 published for student ID 169328 (login ID: pgaudet).
# Score 0.25 published for student ID 106490 (login ID: joy005).
# Score 0.25 published for student ID 95488 (login ID: ldai).
# Score 0.25 published for student ID 108597 (login ID: smkim).
# Score 0.25 published for student ID 133015 (login ID: brzhu).
# Score 0.25 published for student ID 103949 (login ID: h6fu).
# Score 0.25 published for student ID 136327 (login ID: mbach).
# Score 0.25 published for student ID 131574 (login ID: aklam).
# Score 0.25 published for student ID 102630 (login ID: shw050).
# Score 0.25 published for student ID 68706 (login ID: dki).
# Score 0.25 published for student ID 169510 (login ID: akamra).
# Score 0.25 published for student ID 128257 (login ID: anslyker).
# Score 0.25 published for student ID 96265 (login ID: jyl013).
# Score 0.25 published for student ID 130660 (login ID: jsimpauco).
# Score 0.25 published for student ID 137768 (login ID: p1nair).
# Score 0.25 published for student ID 108758 (login ID: lto).
# Score 0.25 published for student ID 105565 (login ID: bzou).
# Score 0.25 published for student ID 129728 (login ID: amkao).
# Score 0.25 published for student ID 102671 (login ID: sbramire).
# Score 0.25 published for student ID 134153 (login ID: xjramirez).
# Score 0.25 published for student ID 96039 (login ID: anag).
# Score 0.25 published for student ID 100638 (login ID: aghai).
# Score 0.25 published for student ID 105349 (login ID: hohu).
# Score 0.25 published for student ID 136616 (login ID: asonti).
# Score 0.25 published for student ID 96826 (login ID: yiz036).
# Score 0.25 published for student ID 167961 (login ID: yax016).
# Score 0.25 published for student ID 166891 (login ID: tithai).
# Score 0.25 published for student ID 128795 (login ID: huy005).
# Score 0.25 published for student ID 157393 (login ID: del021).
# Score 0.25 published for student ID 130264 (login ID: xuh011).
# Score 0.25 published for student ID 137866 (login ID: rzsun).
# Score 0.25 published for student ID 96744 (login ID: kqu).
# Score 0.25 published for student ID 128882 (login ID: vhinds).
# Score 0.25 published for student ID 133337 (login ID: prebala).
# Score 0.25 published for student ID 165074 (login ID: alz007).
# Score 0.25 published for student ID 105137 (login ID: asierra).
# Score 0.25 published for student ID 107315 (login ID: khpark).
# Score 0.25 published for student ID 108289 (login ID: ssankavaram).
# Score 0.25 published for student ID 96896 (login ID: mag026).
# Score 0.25 published for student ID 171542 (login ID: dithomas).
# Score 0.25 published for student ID 133651 (login ID: chl147).
# Score 0.25 published for student ID 63257 (login ID: k6qin).
# Score 0.25 published for student ID 107713 (login ID: eheffernan).
# Score 0.25 published for student ID 166981 (login ID: fenriquez).
# Score 0.25 published for student ID 100748 (login ID: zhx003).
# Score 0.25 published for student ID 129783 (login ID: nghosh).
# Score 0.25 published for student ID 168449 (login ID: mec009).
# Score 0.25 published for student ID 66260 (login ID: nregli).
# Score 0.25 published for student ID 95913 (login ID: vlohia).
# Score 0.25 published for student ID 170938 (login ID: nako).
# Score 0.25 published for student ID 103575 (login ID: bsepulve).
# Score 0.25 published for student ID 107634 (login ID: cdermanuelian).
# Score 0.25 published for student ID 134401 (login ID: hushan).
# Score 0.25 published for student ID 108648 (login ID: bfernandez).
# Score 0.25 published for student ID 169638 (login ID: haw086).
# Score 0.25 published for student ID 131066 (login ID: gjl001).
# Score 0.25 published for student ID 171134 (login ID: mkhawaja).
# Score 0.25 published for student ID 129817 (login ID: jtutak).
# Score 0.25 published for student ID 99397 (login ID: mesantos).
# Score 0.25 published for student ID 139799 (login ID: hashcroft).
# Score 0.25 published for student ID 126284 (login ID: tibao).
# Score 0.25 published for student ID 133112 (login ID: emn005).
# Score 0.25 published for student ID 100805 (login ID: bbhaber).
# Score 0.25 published for student ID 167197 (login ID: efg004).
# Score 0.25 published for student ID 134440 (login ID: kjchou).
# Score 0.25 published for student ID 104875 (login ID: m1tam).
# Score 0.25 published for student ID 129236 (login ID: kuw010).
# Score 0.25 published for student ID 134467 (login ID: mmuruganandam).
# Score 0.25 published for student ID 130947 (login ID: swchan).
# Score 0.25 published for student ID 99845 (login ID: a2vazque).
# Score 0.25 published for student ID 168241 (login ID: ttp007).
# Score 0.25 published for student ID 135379 (login ID: jkaminsky).
# Score 0.25 published for student ID 170853 (login ID: kan024).
# Score 0.25 published for student ID 134312 (login ID: s2malik).
# Score 0.25 published for student ID 132502 (login ID: kponce).
# Score 0.25 published for student ID 103423 (login ID: yaxiao).
# Score 0.25 published for student ID 131732 (login ID: p3xu).
# Score 0.25 published for student ID 94470 (login ID: arasin).
# Score 0.25 published for student ID 127412 (login ID: bquijada).
# Score 0.25 published for student ID 58473 (login ID: jup006).
# Score 0.25 published for student ID 101920 (login ID: skaroval).
# Score 0.25 published for student ID 95531 (login ID: n2lam).
# Score 0.25 published for student ID 26607 (login ID: asagundo).
# Score 0.25 published for student ID 104873 (login ID: ysingh).
# Score 0.25 published for student ID 107716 (login ID: sgaribayzaguilan).
# Score 0.25 published for student ID 96240 (login ID: dekhan).
# Score 0.25 published for student ID 134875 (login ID: ctomlin).
# Score 0.25 published for student ID 130702 (login ID: xig001).
# Score 0.25 published for student ID 170169 (login ID: cht019).
# Score 0.25 published for student ID 96233 (login ID: dshin).
# Score 0.25 published for student ID 132074 (login ID: aravishankar).
# Score 0.25 published for student ID 134367 (login ID: cll006).
# Score 0.25 published for student ID 95061 (login ID: npareddy).
# Score 0.25 published for student ID 98982 (login ID: ctn005).
# Score 0.25 published for student ID 133359 (login ID: bsathappan).
# Score 0.25 published for student ID 104871 (login ID: spamudji).
# Score 0.25 published for student ID 97046 (login ID: azhuchou).
# Score 0.25 published for student ID 101569 (login ID: tbmai).
# Score 0.25 published for student ID 129316 (login ID: arobertson).
# Score 0.25 published for student ID 139261 (login ID: jhw009).
# Score 0.25 published for student ID 171360 (login ID: basami).
# Score 0.25 published for student ID 166952 (login ID: bdubois).
# Score 0.25 published for student ID 107869 (login ID: hbrownell).
# Score 0.25 published for student ID 168713 (login ID: rlizaranmolina).
# Score 0.25 published for student ID 108027 (login ID: dcarrion).
# Score 0.25 published for student ID 133030 (login ID: mhle).
# Score 0.25 published for student ID 139090 (login ID: vhu).
# Score 0.25 published for student ID 105081 (login ID: r6sanche).
# Score 0.25 published for student ID 137403 (login ID: kkray).
# Score 0.25 published for student ID 168298 (login ID: mmckenziegarand).
# Score 0.25 published for student ID 108302 (login ID: mlholland).
# Score 0.25 published for student ID 139975 (login ID: bbudiputra).
# Score 0.25 published for student ID 170159 (login ID: jartley).
# Score 0.25 published for student ID 130744 (login ID: choman).
# Score 0.25 published for student ID 94249 (login ID: zhz044).
# Score 0.25 published for student ID 108148 (login ID: e2sun).
# Score 0.25 published for student ID 97103 (login ID: zedu).
# Score 0.25 published for student ID 99288 (login ID: c4yan).
# Score 0.25 published for student ID 129850 (login ID: hvphan).
# Score 0.25 published for student ID 168962 (login ID: hykung).
# Score 0.25 published for student ID 104244 (login ID: jnishi).
# Score 0.25 published for student ID 96286 (login ID: xiy005).
# Score 0.25 published for student ID 101983 (login ID: trtruong).
# Score 0.25 published for student ID 130151 (login ID: enchin).
# Score 0.25 published for student ID 167080 (login ID: aaboushaaban).
# Score 0.25 published for student ID 162694 (login ID: hic001).
# Score 0.25 published for student ID 169757 (login ID: bsison).
# Score 0.25 published for student ID 131674 (login ID: yih045).
# Score 0.25 published for student ID 132711 (login ID: jtcastillo).
# Score 0.25 published for student ID 134113 (login ID: sjc003).
# Score 0.25 published for student ID 166937 (login ID: svaldimarsdottir).
# Score 0.25 published for student ID 101023 (login ID: rmali).
# Score 0.25 published for student ID 136633 (login ID: yag007).
# Score 0.25 published for student ID 131814 (login ID: ejxiong).
# Score 0.25 published for student ID 45393 (login ID: nekeodar).
# Score 0.25 published for student ID 163522 (login ID: i1cheng).
# Score 0.25 published for student ID 133356 (login ID: x1shu).
# Score 0.25 published for student ID 15469 (login ID: h2choi).
# Score 0.25 published for student ID 129220 (login ID: rdwong).
# Score 0.25 published for student ID 127733 (login ID: kmvu).
# Score 0.25 published for student ID 103541 (login ID: juw024).
# Score 0.25 published for student ID 95029 (login ID: yiw072).
# Score 0.25 published for student ID 134408 (login ID: jstreett).
# Score 0.25 published for student ID 24678 (login ID: rpeng).
# Score 0.25 published for student ID 140061 (login ID: kjsong).
# Score 0.25 published for student ID 102641 (login ID: v8gonzal).
# Score 0.25 published for student ID 132420 (login ID: chao).
# Score 0.25 published for student ID 129432 (login ID: nchepuri).
# Score 0.25 published for student ID 167673 (login ID: j8ramos).
# Score 0.25 published for student ID 129125 (login ID: apimple).
# Score 0.25 published for student ID 129312 (login ID: fjiang).
# Score 0.25 published for student ID 170870 (login ID: zil089).
# Score 0.25 published for student ID 132525 (login ID: khw001).
# Score 0.25 published for student ID 140407 (login ID: npantfoerder).
# Score 0.25 published for student ID 136152 (login ID: jrjimenez).
# Score 0.25 published for student ID 132061 (login ID: prkhanna).
# Score 0.25 published for student ID 98047 (login ID: k6ma).
# Score 0.25 published for student ID 135976 (login ID: htonnu).
# Score 0.25 published for student ID 167191 (login ID: yamazaheri).
# Score 0.25 published for student ID 141132 (login ID: jdegraaf).
# Score 0.25 published for student ID 107429 (login ID: spuri).
# Score 0.25 published for student ID 96236 (login ID: dzjiang).
# Score 0.25 published for student ID 96131 (login ID: dam001).
# Score 0.25 published for student ID 130704 (login ID: nal008).
# Score 0.25 published for student ID 100406 (login ID: nbajaj).
# Score 0.25 published for student ID 140376 (login ID: yic079).
# Score 0.25 published for student ID 105419 (login ID: lil010).
# Score 0.25 published for student ID 131623 (login ID: xif001).
# Score 0.25 published for student ID 132336 (login ID: shw081).
# Score 0.25 published for student ID 131018 (login ID: apurohit).
# Score 0.25 published for student ID 108552 (login ID: lyazouri).
# Score 0.25 published for student ID 95738 (login ID: qhui).
# Score 0.25 published for student ID 168007 (login ID: senkhjargal).
# Score 0.25 published for student ID 99596 (login ID: emiranda).
# Score 0.25 published for student ID 137772 (login ID: adagrawal).
# Score 0.25 published for student ID 132115 (login ID: achavarria).
# Score 0.25 published for student ID 107367 (login ID: smejia).
# Score 0.25 published for student ID 138189 (login ID: ihamid).
# Score 0.25 published for student ID 136387 (login ID: kewoo).
# Score 0.25 published for student ID 107548 (login ID: ajuljulian).
# Score 0.25 published for student ID 129253 (login ID: jiz147).
# Score 0.25 published for student ID 99674 (login ID: ipendlet).
# Score 0.25 published for student ID 102965 (login ID: mmelkony).
# Score 0.25 published for student ID 4273 (login ID: akn022).
# Score 0.25 published for student ID 93612 (login ID: gprabhak).
# Score 0.25 published for student ID 101595 (login ID: z4wan).
# Score 0.25 published for student ID 133409 (login ID: mamorera).
# Score 0.25 published for student ID 127729 (login ID: spital).
# Score 0.25 published for student ID 103272 (login ID: vshu).
# Score 0.25 published for student ID 132129 (login ID: jtanurdjaja).
# Score 0.25 published for student ID 128522 (login ID: niquach).
# Score 0.25 published for student ID 129639 (login ID: yuw135).
# Score 0.25 published for student ID 103513 (login ID: rhli).
# Score 0.25 published for student ID 170865 (login ID: hsy002).
# Score 0.25 published for student ID 168441 (login ID: karaj).
# Score 0.25 published for student ID 131821 (login ID: saliang).
# Score 0.25 published for student ID 107369 (login ID: kwchin).
# Score 0.25 published for student ID 107645 (login ID: a1mishra).
# Score 0.25 published for student ID 136579 (login ID: dgines).
# Score 0.25 published for student ID 134859 (login ID: ziz057).
# Score 0.25 published for student ID 130922 (login ID: s4kumar).
# Score 0.25 published for student ID 139361 (login ID: kal030).
# Score 0.25 published for student ID 135771 (login ID: pgaikwad).
# Score 0.25 published for student ID 48388 (login ID: atvilays).
# Score 0.25 published for student ID 169598 (login ID: kew027).
# Score 0.25 published for student ID 97451 (login ID: s1rai).
# Score 0.25 published for student ID 130921 (login ID: hsflores).
# Score 0.25 published for student ID 100879 (login ID: pyhui).
# Score 0.25 published for student ID 99247 (login ID: svirk).
# Score 0.25 published for student ID 170353 (login ID: ababoescu).
# Score 0.25 published for student ID 168989 (login ID: bdioneda).
# Score 0.25 published for student ID 107686 (login ID: aborjasquintanilla).
# Score 0.25 published for student ID 129503 (login ID: sgong).
# Score 0.25 published for student ID 97105 (login ID: r1singh).
# Score 0.25 published for student ID 129664 (login ID: fetang).
# Score 0.25 published for student ID 135792 (login ID: eldelrosario).
# Score 0.25 published for student ID 106329 (login ID: kvankirk).
# Score 0.25 published for student ID 168979 (login ID: samann).
# Score 0.25 published for student ID 127201 (login ID: janayagarcia).
# Score 0.25 published for student ID 170686 (login ID: lfasting).
# Score 0.25 published for student ID 133705 (login ID: baphan).
# Score 0.25 published for student ID 95700 (login ID: sragarwa).
# Score 0.25 published for student ID 169317 (login ID: zpun).
# Score 0.25 published for student ID 102711 (login ID: pmondrag).
# Score 0.25 published for student ID 99613 (login ID: z7peng).
# Score 0.25 published for student ID 132235 (login ID: arshukla).
# Score 0.25 published for student ID 100057 (login ID: t8wu).
# Score 0.25 published for student ID 101860 (login ID: jyyip).
# Score 0.25 published for student ID 169794 (login ID: rojin).
# Score 0.25 published for student ID 133412 (login ID: siw031).
# Score 0.25 published for student ID 103446 (login ID: pseck).
# Score 0.25 published for student ID 133026 (login ID: mszeto).
# Score 0.25 published for student ID 134352 (login ID: hhshin).
# Score 0.25 published for student ID 127844 (login ID: luz010).
# Score 0.25 published for student ID 131757 (login ID: ahvu).
# Score 0.25 published for student ID 171822 (login ID: e4zhou).
# Score 0.25 published for student ID 167662 (login ID: jchowe).
# Score 0.25 published for student ID 97892 (login ID: smai).
# Score 0.25 published for student ID 166554 (login ID: gpong).
# Score 0.25 published for student ID 129207 (login ID: j1ouyang).
# Score 0.25 published for student ID 103007 (login ID: stalanki).
# Score 0.25 published for student ID 30341 (login ID: cktan).
# Score 0.25 published for student ID 135005 (login ID: shirota).
# Score 0.25 published for student ID 167849 (login ID: rkant).
# Score 0.25 published for student ID 131533 (login ID: acalza).
# Score 0.25 published for student ID 104765 (login ID: khn009).
# Score 0.25 published for student ID 92025 (login ID: e7rodrig).
# Score 0.25 published for student ID 141212 (login ID: acrawley).
# Score 0.25 published for student ID 108019 (login ID: bbeeson).
# Score 0.25 published for student ID 138671 (login ID: mgliu).
# Score 0.25 published for student ID 106672 (login ID: pjtran).
# Score 0.25 published for student ID 136075 (login ID: jshyu).
# Score 0.25 published for student ID 96969 (login ID: nihegde).
# Score 0.25 published for student ID 99726 (login ID: jevalle).
# Score 0.25 published for student ID 125371 (login ID: lgranger).
# Score 0.25 published for student ID 131086 (login ID: h3cai).
# Score 0.25 published for student ID 129504 (login ID: hlschwartz).
# Score 0.25 published for student ID 134507 (login ID: jum004).
# Score 0.25 published for student ID 109592 (login ID: shz040).
# Score 0.25 published for student ID 99379 (login ID: swmenon).
# Score 0.25 published for student ID 171065 (login ID: osimonds).
# Score 0.25 published for student ID 132152 (login ID: key009).
# Score 0.25 published for student ID 136785 (login ID: ctwalsh).
# Score 0.25 published for student ID 131495 (login ID: rpenchala).
# Score 0.25 published for student ID 107271 (login ID: bhacia).
# Score 0.25 published for student ID 168613 (login ID: gfeghali).
# Score 0.25 published for student ID 134098 (login ID: m3shen).
# Score 0.25 published for student ID 132164 (login ID: adarun).
# Score 0.25 published for student ID 104277 (login ID: wuli).
# Score 0.25 published for student ID 95904 (login ID: lez002).
# Score 0.25 published for student ID 132773 (login ID: htse).
# Score 0.25 published for student ID 173394 (login ID: asubbarao).
# Score 0.25 published for student ID 134170 (login ID: aacameron).
# Score 0.25 published for student ID 136924 (login ID: daw010).
# Score 0.25 published for student ID 166905 (login ID: gihoang).
# Score 0.25 published for student ID 97061 (login ID: yuw096).
# Score 0.25 published for student ID 171056 (login ID: jkarim).
# Score 0.25 published for student ID 171654 (login ID: kekhlassi).
# Score 0.25 published for student ID 168611 (login ID: anarasimhan).
# Score 0.25 published for student ID 136257 (login ID: jig015).
# Score 0.25 published for student ID 96800 (login ID: lballest).
# Score 0.25 published for student ID 135894 (login ID: vkwan).
# Score 0.25 published for student ID 126239 (login ID: r2zhu).
# Score 0.25 published for student ID 107572 (login ID: sat001).
# Score 0.25 published for student ID 99612 (login ID: crishi).
# Score 0.25 published for student ID 100900 (login ID: f3li).
# Score 0.25 published for student ID 128109 (login ID: yuj036).
# Score 0.25 published for student ID 168256 (login ID: gluengowoods).
# Score 0.25 published for student ID 131330 (login ID: yul196).
# Score 0.25 published for student ID 160049 (login ID: asmithwick).
# Score 0.25 published for student ID 138313 (login ID: sboddy).
# Score 0.25 published for student ID 133033 (login ID: rsunku).
# Score 0.25 published for student ID 170551 (login ID: tsharifi).
# Score 0.25 published for student ID 136797 (login ID: s4min).
# Score 0.25 published for student ID 133822 (login ID: evchan).
# Score 0.25 published for student ID 132703 (login ID: nwzhang).
# Score 0.25 published for student ID 105446 (login ID: yyanagawa).
# Score 0.25 published for student ID 101886 (login ID: pklam).
# Score 0.25 published for student ID 97235 (login ID: tyyu).
# Score 0.25 published for student ID 132220 (login ID: ccl011).
# Score 0.25 published for student ID 136033 (login ID: j5dai).
# Score 0.25 published for student ID 137367 (login ID: jweconomy).
# Score 0.25 published for student ID 132227 (login ID: l1zhuo).
# Score 0.25 published for student ID 102402 (login ID: qihou).
# Score 0.25 published for student ID 134557 (login ID: ziqiu).
# Score 0.25 published for student ID 131549 (login ID: bigao).
# Score 0.25 published for student ID 96899 (login ID: r6yang).
# Score 0.25 published for student ID 95060 (login ID: nboloori).
# Score 0.25 published for student ID 126395 (login ID: otang).
# Score 0.25 published for student ID 136202 (login ID: bwelles).
# Score 0.25 published for student ID 170684 (login ID: mic035).
# Score 0.25 published for student ID 94407 (login ID: sdsteven).
# Score 0.25 published for student ID 102793 (login ID: yechoi).
# Score 0.25 published for student ID 168099 (login ID: jih101).
# Score 0.25 published for student ID 96202 (login ID: l3wang).
# Score 0.25 published for student ID 106164 (login ID: mdimitropoulouka).
# Score 0.25 published for student ID 10097 (login ID: haw189).
# Score 0.25 published for student ID 135799 (login ID: nthiyagarajan).
# Score 0.25 published for student ID 9382 (login ID: naalami).
# Score 0.25 published for student ID 129324 (login ID: wkam).
# Score 0.25 published for student ID 136823 (login ID: jgamm).
# Score 0.25 published for student ID 97203 (login ID: y6tang).
# Score 0.25 published for student ID 105019 (login ID: anmiao).
# Score 0.25 published for student ID 95712 (login ID: jzwu).
# Score 0.25 published for student ID 167018 (login ID: v1prado).
# Score 0.25 published for student ID 128347 (login ID: chl125).
# Score 0.25 published for student ID 132637 (login ID: c5jiang).
# Score 0.25 published for student ID 128169 (login ID: narumugam).
# Score 0.25 published for student ID 133383 (login ID: y2bu).
# Score 0.25 published for student ID 166846 (login ID: miz030).
# Score 0.25 published for student ID 137002 (login ID: key010).
# Score 0.25 published for student ID 133108 (login ID: mamontano).
# Score 0.25 published for student ID 168471 (login ID: k9kang).
# Score 0.25 published for student ID 134432 (login ID: lsfleig).
# Score 0.25 published for student ID 100011 (login ID: jpon).
# Score 0.25 published for student ID 130912 (login ID: ouli).
# Score 0.25 published for student ID 168429 (login ID: etwaters).
# Score 0.25 published for student ID 167025 (login ID: aaverbuj).
# Score 0.25 published for student ID 100080 (login ID: ajiang).
# Score 0.25 published for student ID 128855 (login ID: ton002).
# Score 0.25 published for student ID 173277 (login ID: jasabio).
# Score 0.25 published for student ID 100907 (login ID: mbuan).
# Score 0.25 published for student ID 129391 (login ID: yuhung).
# Score 0.25 published for student ID 97257 (login ID: rhlin).
# Score 0.25 published for student ID 129500 (login ID: b2zhu).
# Score 0.25 published for student ID 96312 (login ID: pputtapa).
# Score 0.25 published for student ID 101491 (login ID: kfleisch).
# Score 0.25 published for student ID 172884 (login ID: bop002).
# Score 0.25 published for student ID 131104 (login ID: yilou).
# Score 0.25 published for student ID 134831 (login ID: sevtimova).
# Score 0.25 published for student ID 106002 (login ID: jul050).
# Score 0.25 published for student ID 101556 (login ID: gjchen).
# Score 0.25 published for student ID 103156 (login ID: jgow).
# Score 0.25 published for student ID 133569 (login ID: jcc002).
# Score 0.25 published for student ID 107542 (login ID: ejlau).
# Score 0.25 published for student ID 96754 (login ID: hgurusan).
# Score 0.25 published for student ID 96332 (login ID: kpansuri).
# Score 0.25 published for student ID 133353 (login ID: a1agrawal).
# Score 0.25 published for student ID 133913 (login ID: svallumchetla).
# Score 0.25 published for student ID 17362 (login ID: tgibbs).
# Score 0.25 published for student ID 136716 (login ID: nmarthen).
# Score 0.25 published for student ID 127254 (login ID: aklinefelter).
# Score 0.25 published for student ID 131129 (login ID: zhh022).
# Score 0.25 published for student ID 130147 (login ID: karcos).
# Score 0.25 published for student ID 132734 (login ID: mml002).
# Score 0.25 published for student ID 103380 (login ID: a6aggarw).
# Score 0.25 published for student ID 135193 (login ID: jrarreguin).
# Score 0.25 published for student ID 96941 (login ID: nrepetti).
# Score 0.25 published for student ID 128425 (login ID: bfune).
# Score 0.25 published for student ID 98708 (login ID: ruw008).
# Score 0.25 published for student ID 94372 (login ID: nmummala).
# Score 0.25 published for student ID 127805 (login ID: hazou).
# Score 0.25 published for student ID 99841 (login ID: max003).
# Score 0.25 published for student ID 170573 (login ID: zil090).
# Score 0.25 published for student ID 33060 (login ID: suppu).
# Score 0.25 published for student ID 93205 (login ID: jlizarra).
# Score 0.25 published for student ID 108717 (login ID: aapiado).
# Score 0.25 published for student ID 131512 (login ID: mslai).
# Score 0.25 published for student ID 107982 (login ID: sytaylor).
# Score 0.25 published for student ID 134700 (login ID: aujung).
# Score 0.25 published for student ID 124815 (login ID: c8phan).
# Score 0.25 published for student ID 160810 (login ID: mdkawakami).
# Score 0.25 published for student ID 109883 (login ID: nhn007).
# Score 0.25 published for student ID 164044 (login ID: obychenkov).
# Score 0.25 published for student ID 132230 (login ID: xig003).
# Score 0.25 published for student ID 96199 (login ID: liz009).
# Score 0.25 published for student ID 170346 (login ID: shl127).
# Score 0.25 published for student ID 131582 (login ID: rbaldoz).
# Score 0.25 published for student ID 108721 (login ID: mndiaz).
# Score 0.25 published for student ID 129852 (login ID: k9zhou).
# Score 0.25 published for student ID 104212 (login ID: mis005).
# Score 0.25 published for student ID 167667 (login ID: juw050).
# Score 0.25 published for student ID 171286 (login ID: lim007).
# Score 0.25 published for student ID 169969 (login ID: jig036).
# Score 0.25 published for student ID 107151 (login ID: m5lee).
# Score 0.25 published for student ID 101203 (login ID: dshi).
# Score 0.25 published for student ID 16685 (login ID: rriosram).
# Score 0.25 published for student ID 84206 (login ID: y2lai).
# Score 0.25 published for student ID 15279 (login ID: e8garcia).
# Score 0.25 published for student ID 169677 (login ID: w9chan).
# Score 0.25 published for student ID 127861 (login ID: mil049).
# Score 0.25 published for student ID 102380 (login ID: lazhou).
# Score 0.25 published for student ID 135736 (login ID: ltn011).
# Score 0.25 published for student ID 108445 (login ID: anw002).
# Score 0.25 published for student ID 131877 (login ID: z8yuan).
# Score 0.25 published for student ID 125424 (login ID: gus001).
# Score 0.25 published for student ID 107039 (login ID: rpaquia).
# Score 0.25 published for student ID 100048 (login ID: jal039).
# Score 0.25 published for student ID 135797 (login ID: apremkumar).
# Score 0.25 published for student ID 130112 (login ID: zhz084).
# Score 0.25 published for student ID 167935 (login ID: p1chiang).
# Score 0.25 published for student ID 128164 (login ID: yid016).
# Score 0.25 published for student ID 131668 (login ID: sanarayanan).
# Score 0.25 published for student ID 128163 (login ID: kan005).
# Score 0.25 published for student ID 99424 (login ID: arajiv).
# Score 0.25 published for student ID 169672 (login ID: ezdeng).
# Score 0.25 published for student ID 101352 (login ID: vsastry).
# Score 0.25 published for student ID 134387 (login ID: awrussell).
# Score 0.25 published for student ID 133677 (login ID: v7patel).
# Score 0.25 published for student ID 136555 (login ID: jtello).
# Score 0.25 published for student ID 129809 (login ID: cas007).
# Score 0.25 published for student ID 136562 (login ID: yic075).
# Score 0.25 published for student ID 101841 (login ID: claw).
# Score 0.25 published for student ID 133457 (login ID: jedang).
# Score 0.25 published for student ID 96248 (login ID: d5wu).
# Score 0.25 published for student ID 140274 (login ID: azc001).
# Score 0.25 published for student ID 136945 (login ID: tmcooper).
# Score 0.25 published for student ID 127389 (login ID: d3kong).
# Score 0.25 published for student ID 103212 (login ID: amorris).
# Score 0.25 published for student ID 108035 (login ID: kkhoang).
# Score 0.25 published for student ID 99995 (login ID: d7wu).
# Score 0.25 published for student ID 103910 (login ID: akunitad).
# Score 0.25 published for student ID 136073 (login ID: jey013).
# Score 0.25 published for student ID 127238 (login ID: yuz159).
# Score 0.25 published for student ID 128344 (login ID: jih063).
# Score 0.25 published for student ID 133737 (login ID: eyk005).
# Score 0.25 published for student ID 132079 (login ID: keh004).
# Score 0.25 published for student ID 100730 (login ID: molmedo).
# Score 0.25 published for student ID 130681 (login ID: ajvalencia).
# Score 0.25 published for student ID 107002 (login ID: rmeserve).
# Score 0.25 published for student ID 132045 (login ID: a2akbari).
# Score 0.25 published for student ID 107324 (login ID: iachai).
# Score 0.25 published for student ID 170679 (login ID: zakhater).
# Score 0.25 published for student ID 170924 (login ID: bjburke).
# Score 0.25 published for student ID 170014 (login ID: sfrianeza).
# Score 0.25 published for student ID 100403 (login ID: ejao).
# Score 0.25 published for student ID 94971 (login ID: a1ganesa).
# Score 0.25 published for student ID 136784 (login ID: e7song).
# Score 0.25 published for student ID 97237 (login ID: lecai).
# Score 0.25 published for student ID 98371 (login ID: q8chen).
# Score 0.25 published for student ID 133985 (login ID: ckavanagh).
# Score 0.25 published for student ID 138732 (login ID: shsam).
# Score 0.25 published for student ID 132190 (login ID: xih035).
# Score 0.25 published for student ID 95006 (login ID: jyip).
# Score 0.25 published for student ID 130300 (login ID: jil237).
# Score 0.25 published for student ID 138819 (login ID: jmcole).
# Score 0.25 published for student ID 135973 (login ID: ddonskoy).
# Score 0.25 published for student ID 131083 (login ID: erk004).
# Score 0.25 published for student ID 95289 (login ID: y7qin).
# Score 0.25 published for student ID 129335 (login ID: dfeliton).
# Score 0.25 published for student ID 141488 (login ID: kyl011).
# Score 0.25 published for student ID 140172 (login ID: piw001).
# Score 0.25 published for student ID 132225 (login ID: kjk004).
# Score 0.25 published for student ID 134395 (login ID: pkatukojwala).
# Score 0.25 published for student ID 97234 (login ID: bjackola).
# Score 0.25 published for student ID 134050 (login ID: kku).
# Score 0.25 published for student ID 133630 (login ID: brchu).
# Score 0.25 published for student ID 128282 (login ID: unaik).
# Score 0.25 published for student ID 104848 (login ID: tpeterso).
# Score 0.25 published for student ID 127796 (login ID: n1rashid).
# Score 0.25 published for student ID 107501 (login ID: z4han).
# Score 0.25 published for student ID 158104 (login ID: arsureshkumar).
# Score 0.25 published for student ID 98313 (login ID: mdulansk).
# Score 0.25 published for student ID 107161 (login ID: drovira).
# Score 0.25 published for student ID 135159 (login ID: gbutters).
# Score 0.25 published for student ID 129567 (login ID: anw010).
# Score 0.25 published for student ID 133445 (login ID: kham).
# Score 0.25 published for student ID 136582 (login ID: jil249).
# Score 0.25 published for student ID 130763 (login ID: eplong).
# Score 0.25 published for student ID 98017 (login ID: y4zhong).
# Score 0.25 published for student ID 132491 (login ID: chc057).
# Score 0.25 published for student ID 99704 (login ID: hwk001).
# Score 0.25 published for student ID 132533 (login ID: kkla).
# Score 0.25 published for student ID 130719 (login ID: fepeng).
# Score 0.25 published for student ID 95825 (login ID: yiz029).
# Score 0.25 published for student ID 134302 (login ID: estratford).
# Score 0.25 published for student ID 124614 (login ID: sbnorthrop).
# Score 0.25 published for student ID 135381 (login ID: sschlagheck).
# Score 0.25 published for student ID 68026 (login ID: dnkim).
# Score 0.25 published for student ID 137113 (login ID: h9cheng).
# Score 0.25 published for student ID 127779 (login ID: s7liang).
# Score 0.25 published for student ID 95337 (login ID: ktn013).
# Score 0.25 published for student ID 105246 (login ID: gdietz).
# Score 0.25 published for student ID 133551 (login ID: grquach).
# Score 0.25 published for student ID 167989 (login ID: rin002).
# Score 0.25 published for student ID 102672 (login ID: iroque).
# Score 0.25 published for student ID 165981 (login ID: ajayamohan).
# Score 0.25 published for student ID 104952 (login ID: tjoel).
# Score 0.25 published for student ID 98083 (login ID: anprasad).
# Score 0.25 published for student ID 134761 (login ID: etl003).
# Score 0.25 published for student ID 168166 (login ID: jariss).
# Score 0.25 published for student ID 127808 (login ID: jiz145).
# Score 0.25 published for student ID 131585 (login ID: ealopez).
# Score 0.25 published for student ID 108020 (login ID: lgasser).
# Score 0.25 published for student ID 99571 (login ID: jazheng).
# Score 0.25 published for student ID 129309 (login ID: mnleong).
# Score 0.25 published for student ID 169157 (login ID: arakha).
# Score 0.25 published for student ID 139887 (login ID: j3ko).
# Score 0.25 published for student ID 103297 (login ID: yek003).
# Score 0.25 published for student ID 169380 (login ID: n1shinde).
# Score 0.25 published for student ID 129102 (login ID: accalibuso).
# Score 0.25 published for student ID 107802 (login ID: bthome).
# Score 0.25 published for student ID 108008 (login ID: jjwu).
# Score 0.25 published for student ID 130232 (login ID: arkonnova).
# Score 0.25 published for student ID 168159 (login ID: hojia).
# Score 0.25 published for student ID 103047 (login ID: haz042).
# Score 0.25 published for student ID 164723 (login ID: fdiamond).
# Score 0.25 published for student ID 168309 (login ID: z4cai).
# Score 0.25 published for student ID 95295 (login ID: json).
# Score 0.25 published for student ID 171627 (login ID: zlim).
# Score 0.25 published for student ID 129696 (login ID: fdong).
# Score 0.25 published for student ID 103623 (login ID: hey001).
# Score 0.25 published for student ID 99005 (login ID: kefong).
# Score 0.25 published for student ID 52040 (login ID: knelakon).
# Score 0.25 published for student ID 96271 (login ID: phelcl).
# Score 0.25 published for student ID 128912 (login ID: vhasthi).
# Score 0.25 published for student ID 95984 (login ID: t8li).
# Score 0.25 published for student ID 136035 (login ID: r3xiao).
# Score 0.25 published for student ID 133124 (login ID: a2ma).
# Score 0.25 published for student ID 104930 (login ID: abanwait).
# Score 0.25 published for student ID 168375 (login ID: hhai).
# Score 0.25 published for student ID 100151 (login ID: sgoh).
# Score 0.25 published for student ID 135971 (login ID: pssanchez).
# Score 0.25 published for student ID 170314 (login ID: joh032).
# Score 0.25 published for student ID 133607 (login ID: jaw018).
# Score 0.25 published for student ID 168424 (login ID: ervu).
# Score 0.25 published for student ID 132979 (login ID: nol001).
# Score 0.25 published for student ID 106148 (login ID: tpagela).
# Score 0.25 published for student ID 171110 (login ID: v9wong).
# Score 0.25 published for student ID 134501 (login ID: ntchung).
# Score 0.25 published for student ID 171314 (login ID: tkk002).
# Score 0.25 published for student ID 16293 (login ID: jakwak).
# Score 0.25 published for student ID 170760 (login ID: wcw003).
# Score 0.25 published for student ID 131007 (login ID: xushi).
# Score 0.25 published for student ID 156355 (login ID: arraja).
# Score 0.25 published for student ID 97137 (login ID: stchavez).
